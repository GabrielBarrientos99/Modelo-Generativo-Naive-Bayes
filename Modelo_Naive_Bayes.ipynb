# %% [markdown]
# # Construcción de un Modelo Generativo de Lenguaje con Naive Bayes
#
# Naive Bayes es un algoritmo basado en la probabilidad condicional que asume independencia entre las características. En el contexto de los modelos de lenguaje, se utiliza para predecir la probabilidad de una palabra en una secuencia dada, basándose en el conteo de frecuencias.
#
# ---
#
# ### 1. El Teorema de Bayes
#
# El Teorema de Bayes describe la relación entre la probabilidad condicional de dos eventos. Matemáticamente, se expresa como:
#
# $$
# P(A \mid B) = \frac{P(B \mid A) P(A)}{P(B)}
# $$
#
# Donde:
# - \( P(A | B) \) es la probabilidad posterior, es decir, la probabilidad de que ocurra el evento \( A \) dado que ha ocurrido el evento \( B \).
# - \( P(B | A) \) es la probabilidad condicional de \( B \) dado \( A \).
# - \( P(A) \) es la probabilidad previa de \( A \) (la probabilidad de que ocurra \( A \) sin información adicional).
# - \( P(B) \) es la probabilidad marginal de \( B \).
#
# Este teorema es la base de los clasificadores de Naive Bayes.
#
# ---
#
#
#
# ### 2. Fórmula General de Naive Bayes en un contexto de Modelo de Lenguaje
# Dada una secuencia de palabras , queremos predecir la probabilidad de la secuencia completa:
#
# $$
# P(w_1, w_2, \dots, w_n) = P(w_1) P(w_2 | w_1) P(w_3 | w_1, w_2) \dots P(w_n | w_1, w_2, \dots, w_{n-1})
# $$
#
#
# Naive Bayes simplifica este cálculo asumiendo que cada palabra depende únicamente de la palabra anterior, lo que da lugar al modelo de n-gramas.
# Para el caso de bigramas:
#
# $$
# P(w_1, w_2, \dots, w_n) = P(w_1) P(w_2 | w_1) P(w_3 | w_2) \dots P(w_n | w_{n-1})
# $$

# %%
import re
# Definimos nuestro tokenizador a palabras

def tokenizer(corpus:str)->list:
    # Convertimos a minuscula
    new_corpus = corpus.lower()
    pattern = re.compile(r'\b\w+\b')
    return re.findall(pattern, new_corpus)

corpus = "Como estas te veo bien por ahora"
tokenizer(corpus)
# Out:
# ['como', 'estas', 'te', 'veo', 'bien', 'por', 'ahora']

# %%
import re

pattern = re.compile(r'\b\w+\b|[.,?"]')
re.findall(pattern,'hola como estas')
# Out:
# ['hola', 'como', 'estas']

# %%
from collections import defaultdict

# Definimos una funcion que cuenta los unigramas, bigramas, trigramas y cuatrigramas
def get_unigrams_bigrams_trigramas_cuatrigramas(corpus_tokenized: list) -> (dict, dict, dict, dict):
    # Usamos defaultdict para evitar tener que inicializar las claves manualmente
    unigrams = defaultdict(int)
    bigrams = defaultdict(int)
    trigramas = defaultdict(int)
    cuatrigramas = defaultdict(int)

    n = len(corpus_tokenized)

    if n < 4 :
        return None,None,None,None

    for i in range(n - 3):
        unigram = corpus_tokenized[i]
        bigram = (corpus_tokenized[i], corpus_tokenized[i + 1])
        trigrama = (corpus_tokenized[i], corpus_tokenized[i + 1], corpus_tokenized[i + 2])
        cuatrigrama = (corpus_tokenized[i], corpus_tokenized[i + 1], corpus_tokenized[i + 2], corpus_tokenized[i + 3])

        # Los contadores se incrementan automáticamente
        unigrams[unigram] += 1
        bigrams[bigram] += 1
        trigramas[trigrama] += 1
        cuatrigramas[cuatrigrama] += 1


    # Agregamos los 3 ultimos unigramas
    unigrams[corpus_tokenized[n - 3]] += 1
    unigrams[corpus_tokenized[n - 2]] += 1
    unigrams[corpus_tokenized[n - 1]] += 1
    # Agregamos los 2 ultimos bigramas
    bigrams[(corpus_tokenized[n - 3],corpus_tokenized[n - 2])] += 1
    bigrams[(corpus_tokenized[n - 2],corpus_tokenized[n - 1])] += 1

    # Agregamos el ultimo trigrama
    trigrama = (corpus_tokenized[n - 3],corpus_tokenized[n - 2],corpus_tokenized[n - 1])
    trigramas[trigrama] += 1

    return dict(unigrams), dict(bigrams), dict(trigramas), dict(cuatrigramas)


corpus = """
El Misterio del Bosque Encantado

Una fría tarde de otoño, Elena decidió explorar el viejo bosque que se encontraba a las afueras del pueblo. La gente solía decir que aquel lugar estaba maldito, que quienes se aventuraban demasiado en sus profundidades no regresaban jamás. Pero a Elena no le importaban esas historias; tenía una curiosidad insaciable y un espíritu aventurero que no conocía el miedo.
Al adentrarse en el bosque, la luz del sol comenzó a desvanecerse entre los árboles, creando sombras alargadas que parecían moverse a su alrededor. A cada paso, las hojas secas crujían bajo sus botas, resonando en la inquietante tranquilidad que envolvía el lugar. Todo estaba en silencio, excepto por el ocasional canto de un cuervo en lo alto.
De repente, a lo lejos, divisó una figura. Parecía un niño, inmóvil, con una capa oscura que se confundía con los troncos de los árboles. Elena, intrigada, decidió acercarse. Cuanto más se aproximaba, más claro veía que el niño no parecía estar del todo presente, como si fuera parte del mismo bosque, una extensión más de sus secretos. Al llegar junto a él, sus ojos, de un azul profundo, se encontraron con los de Elena.
—No deberías estar aquí —dijo el niño con una voz suave, casi susurrante.
Elena sintió un escalofrío recorrer su espalda, pero antes de poder responder, la figura desapareció en el aire como si nunca hubiera estado allí. Confusa y con el corazón acelerado, miró a su alrededor, pero el bosque estaba desierto.
Decidió regresar al pueblo, pero el camino que había tomado parecía haber cambiado. Las mismas rutas que antes le resultaban familiares ahora parecían distorsionadas, llevándola en círculos sin un destino claro. El sol se estaba poniendo, y la oscuridad envolvía el lugar cada vez más. Respirando profundamente, Elena intentó calmarse, pero no podía dejar de pensar en las palabras del niño.
Finalmente, después de lo que le pareció una eternidad, encontró la salida. Al llegar al pueblo, notó que algo había cambiado. Las casas lucían más deterioradas, como si hubieran pasado años desde que las había visto por última vez. Al preguntar a los aldeanos, descubrió con horror que había desaparecido por tres días, aunque para ella solo había pasado una tarde.
El bosque encantado había jugado con el tiempo una vez más, dejando a Elena con más preguntas que respuestas y una advertencia clara en su mente: nunca volvería a entrar.
"""

unigrams,bigrams,trigrams,cuatrigrams = get_unigrams_bigrams_trigramas_cuatrigramas(tokenizer(corpus))

# %%
unigrams
# Out:
# {'el': 16,
#  'misterio': 1,
#  'del': 6,
#  'bosque': 6,
#  'encantado': 2,
#  'una': 10,
#  'fría': 1,
#  'tarde': 2,
#  'de': 10,
#  'otoño': 1,
#  'elena': 7,
#  'decidió': 3,
#  'explorar': 1,
#  'viejo': 1,
#  'que': 15,
#  'se': 6,
#  'encontraba': 1,
#  'a': 11,
#  'las': 6,
#  'afueras': 1,
#  'pueblo': 3,
#  'la': 6,
#  'gente': 1,
#  'solía': 1,
#  'decir': 1,
#  'aquel': 1,
#  'lugar': 3,
#  'estaba': 4,
#  'maldito': 1,
#  'quienes': 1,
#  'aventuraban': 1,
#  'demasiado': 1,
#  'en': 9,
#  'sus': 4,
#  'profundidades': 1,
#  'no': 6,
#  'regresaban': 1,
#  'jamás': 1,
#  'pero': 5,
#  'le': 3,
#  'importaban': 1,
#  'esas': 1,
#  'historias': 1,
#  'tenía': 1,
#  'curiosidad': 1,
#  'insaciable': 1,
#  'y': 4,
#  'un': 6,
#  'espíritu': 1,
#  'aventurero': 1,
#  'conocía': 1,
#  'miedo': 1,
#  'al': 6,
#  'adentrarse': 1,
#  'luz': 1,
#  'sol': 2,
#  'comenzó': 1,
#  'desvanecerse': 1,
#  'entre': 1,
#  'los': 5,
#  'árboles': 2,
#  'creando': 1,
#  'sombras': 1,
#  'alargadas': 1,
#  'parecían': 2,
#  'moverse': 1,
#  'su': 4,
#  'alrededor': 2,
#  'cada': 2,
#  'paso': 1,
#  'hojas': 1,
#  'secas': 1,
#  'crujían': 1,
#  'bajo': 1,
#  'botas': 1,
#  'resonando': 1,
#  'inquietante': 1,
#  'tranquilidad': 1,
#  'envolvía': 2,
#  'todo': 2,
#  'silencio': 1,
#  'excepto': 1,
#  'por': 3,
#  'ocasional': 1,
#  'canto': 1,
#  'cuervo': 1,
#  'lo': 3,
#  'alto': 1,
#  'repente': 1,
#  'lejos': 1,
#  'divisó': 1,
#  'figura': 2,
#  'parecía': 3,
#  'niño': 4,
#  'inmóvil': 1,
#  'con': 8,
#  'capa': 1,
#  'oscura': 1,
#  'confundía': 1,
#  'troncos': 1,
#  'intrigada': 1,
#  'acercarse': 1,
#  'cuanto': 1,
#  'más': 7,
#  'aproximaba': 1,
#  'claro': 2,
#  'veía': 1,
#  'estar': 2,
#  'presente': 1,
#  'como': 3,
#  'si': 3,
#  'fuera': 1,
#  'parte': 1,
#  'mismo': 1,
#  'extensión': 1,
#  'secretos': 1,
#  'llegar': 2,
#  'junto': 1,
#  'él': 1,
#  'ojos': 1,
#  'azul': 1,
#  'profundo': 1,
#  'encontraron': 1,
#  'deberías': 1,
#  'aquí': 1,
#  'dijo': 1,
#  'voz': 1,
#  'suave': 1,
#  'casi': 1,
#  'susurrante': 1,
#  'sintió': 1,
#  'escalofrío': 1,
#  'recorrer': 1,
#  'espalda': 1,
#  'antes': 2,
#  'poder': 1,
#  'responder': 1,
#  'desapareció': 1,
#  'aire': 1,
#  'nunca': 2,
#  'hubiera': 1,
#  'estado': 1,
#  'allí': 1,
#  'confusa': 1,
#  'corazón': 1,
#  'acelerado': 1,
#  'miró': 1,
#  'desierto': 1,
#  'regresar': 1,
#  'camino': 1,
#  'había': 6,
#  'tomado': 1,
#  'haber': 1,
#  'cambiado': 2,
#  'mismas': 1,
#  'rutas': 1,
#  'resultaban': 1,
#  'familiares': 1,
#  'ahora': 1,
#  'distorsionadas': 1,
#  'llevándola': 1,
#  'círculos': 1,
#  'sin': 1,
#  'destino': 1,
#  'poniendo': 1,
#  'oscuridad': 1,
#  'vez': 3,
#  'respirando': 1,
#  'profundamente': 1,
#  'intentó': 1,
#  'calmarse': 1,
#  'podía': 1,
#  'dejar': 1,
#  'pensar': 1,
#  'palabras': 1,
#  'finalmente': 1,
#  'después': 1,
#  'pareció': 1,
#  'eternidad': 1,
#  'encontró': 1,
#  'salida': 1,
#  'notó': 1,
#  'algo': 1,
#  'casas': 1,
#  'lucían': 1,
#  'deterioradas': 1,
#  'hubieran': 1,
#  'pasado': 2,
#  'años': 1,
#  'desde': 1,
#  'visto': 1,
#  'última': 1,
#  'preguntar': 1,
#  'aldeanos': 1,
#  'descubrió': 1,
#  'horror': 1,
#  'desaparecido': 1,
#  'tres': 1,
#  'días': 1,
#  'aunque': 1,
#  'para': 1,
#  'ella': 1,
#  'solo': 1,
#  'jugado': 1,
#  'tiempo': 1,
#  'dejando': 1,
#  'preguntas': 1,
#  'respuestas': 1,
#  'advertencia': 1,
#  'clara': 1,
#  'mente': 1,
#  'volvería': 1,
#  'entrar': 1}

# %%
bigrams
# Out:
# {('el', 'misterio'): 1,
#  ('misterio', 'del'): 1,
#  ('del', 'bosque'): 1,
#  ('bosque', 'encantado'): 2,
#  ('encantado', 'una'): 1,
#  ('una', 'fría'): 1,
#  ('fría', 'tarde'): 1,
#  ('tarde', 'de'): 1,
#  ('de', 'otoño'): 1,
#  ('otoño', 'elena'): 1,
#  ('elena', 'decidió'): 1,
#  ('decidió', 'explorar'): 1,
#  ('explorar', 'el'): 1,
#  ('el', 'viejo'): 1,
#  ('viejo', 'bosque'): 1,
#  ('bosque', 'que'): 1,
#  ('que', 'se'): 2,
#  ('se', 'encontraba'): 1,
#  ('encontraba', 'a'): 1,
#  ('a', 'las'): 1,
#  ('las', 'afueras'): 1,
#  ('afueras', 'del'): 1,
#  ('del', 'pueblo'): 1,
#  ('pueblo', 'la'): 1,
#  ('la', 'gente'): 1,
#  ('gente', 'solía'): 1,
#  ('solía', 'decir'): 1,
#  ('decir', 'que'): 1,
#  ('que', 'aquel'): 1,
#  ('aquel', 'lugar'): 1,
#  ('lugar', 'estaba'): 1,
#  ('estaba', 'maldito'): 1,
#  ('maldito', 'que'): 1,
#  ('que', 'quienes'): 1,
#  ('quienes', 'se'): 1,
#  ('se', 'aventuraban'): 1,
#  ('aventuraban', 'demasiado'): 1,
#  ('demasiado', 'en'): 1,
#  ('en', 'sus'): 1,
#  ('sus', 'profundidades'): 1,
#  ('profundidades', 'no'): 1,
#  ('no', 'regresaban'): 1,
#  ('regresaban', 'jamás'): 1,
#  ('jamás', 'pero'): 1,
#  ('pero', 'a'): 1,
#  ('a', 'elena'): 2,
#  ('elena', 'no'): 2,
#  ('no', 'le'): 1,
#  ('le', 'importaban'): 1,
#  ('importaban', 'esas'): 1,
#  ('esas', 'historias'): 1,
#  ('historias', 'tenía'): 1,
#  ('tenía', 'una'): 1,
#  ('una', 'curiosidad'): 1,
#  ('curiosidad', 'insaciable'): 1,
#  ('insaciable', 'y'): 1,
#  ('y', 'un'): 1,
#  ('un', 'espíritu'): 1,
#  ('espíritu', 'aventurero'): 1,
#  ('aventurero', 'que'): 1,
#  ('que', 'no'): 1,
#  ('no', 'conocía'): 1,
#  ('conocía', 'el'): 1,
#  ('el', 'miedo'): 1,
#  ('miedo', 'al'): 1,
#  ('al', 'adentrarse'): 1,
#  ('adentrarse', 'en'): 1,
#  ('en', 'el'): 2,
#  ('el', 'bosque'): 3,
#  ('bosque', 'la'): 1,
#  ('la', 'luz'): 1,
#  ('luz', 'del'): 1,
#  ('del', 'sol'): 1,
#  ('sol', 'comenzó'): 1,
#  ('comenzó', 'a'): 1,
#  ('a', 'desvanecerse'): 1,
#  ('desvanecerse', 'entre'): 1,
#  ('entre', 'los'): 1,
#  ('los', 'árboles'): 2,
#  ('árboles', 'creando'): 1,
#  ('creando', 'sombras'): 1,
#  ('sombras', 'alargadas'): 1,
#  ('alargadas', 'que'): 1,
#  ('que', 'parecían'): 1,
#  ('parecían', 'moverse'): 1,
#  ('moverse', 'a'): 1,
#  ('a', 'su'): 2,
#  ('su', 'alrededor'): 2,
#  ('alrededor', 'a'): 1,
#  ('a', 'cada'): 1,
#  ('cada', 'paso'): 1,
#  ('paso', 'las'): 1,
#  ('las', 'hojas'): 1,
#  ('hojas', 'secas'): 1,
#  ('secas', 'crujían'): 1,
#  ('crujían', 'bajo'): 1,
#  ('bajo', 'sus'): 1,
#  ('sus', 'botas'): 1,
#  ('botas', 'resonando'): 1,
#  ('resonando', 'en'): 1,
#  ('en', 'la'): 1,
#  ('la', 'inquietante'): 1,
#  ('inquietante', 'tranquilidad'): 1,
#  ('tranquilidad', 'que'): 1,
#  ('que', 'envolvía'): 1,
#  ('envolvía', 'el'): 2,
#  ('el', 'lugar'): 2,
#  ('lugar', 'todo'): 1,
#  ('todo', 'estaba'): 1,
#  ('estaba', 'en'): 1,
#  ('en', 'silencio'): 1,
#  ('silencio', 'excepto'): 1,
#  ('excepto', 'por'): 1,
#  ('por', 'el'): 1,
#  ('el', 'ocasional'): 1,
#  ('ocasional', 'canto'): 1,
#  ('canto', 'de'): 1,
#  ('de', 'un'): 2,
#  ('un', 'cuervo'): 1,
#  ('cuervo', 'en'): 1,
#  ('en', 'lo'): 1,
#  ('lo', 'alto'): 1,
#  ('alto', 'de'): 1,
#  ('de', 'repente'): 1,
#  ('repente', 'a'): 1,
#  ('a', 'lo'): 1,
#  ('lo', 'lejos'): 1,
#  ('lejos', 'divisó'): 1,
#  ('divisó', 'una'): 1,
#  ('una', 'figura'): 1,
#  ('figura', 'parecía'): 1,
#  ('parecía', 'un'): 1,
#  ('un', 'niño'): 1,
#  ('niño', 'inmóvil'): 1,
#  ('inmóvil', 'con'): 1,
#  ('con', 'una'): 2,
#  ('una', 'capa'): 1,
#  ('capa', 'oscura'): 1,
#  ('oscura', 'que'): 1,
#  ('se', 'confundía'): 1,
#  ('confundía', 'con'): 1,
#  ('con', 'los'): 2,
#  ('los', 'troncos'): 1,
#  ('troncos', 'de'): 1,
#  ('de', 'los'): 1,
#  ('árboles', 'elena'): 1,
#  ('elena', 'intrigada'): 1,
#  ('intrigada', 'decidió'): 1,
#  ('decidió', 'acercarse'): 1,
#  ('acercarse', 'cuanto'): 1,
#  ('cuanto', 'más'): 1,
#  ('más', 'se'): 1,
#  ('se', 'aproximaba'): 1,
#  ('aproximaba', 'más'): 1,
#  ('más', 'claro'): 1,
#  ('claro', 'veía'): 1,
#  ('veía', 'que'): 1,
#  ('que', 'el'): 1,
#  ('el', 'niño'): 2,
#  ('niño', 'no'): 1,
#  ('no', 'parecía'): 1,
#  ('parecía', 'estar'): 1,
#  ('estar', 'del'): 1,
#  ('del', 'todo'): 1,
#  ('todo', 'presente'): 1,
#  ('presente', 'como'): 1,
#  ('como', 'si'): 3,
#  ('si', 'fuera'): 1,
#  ('fuera', 'parte'): 1,
#  ('parte', 'del'): 1,
#  ('del', 'mismo'): 1,
#  ('mismo', 'bosque'): 1,
#  ('bosque', 'una'): 1,
#  ('una', 'extensión'): 1,
#  ('extensión', 'más'): 1,
#  ('más', 'de'): 1,
#  ('de', 'sus'): 1,
#  ('sus', 'secretos'): 1,
#  ('secretos', 'al'): 1,
#  ('al', 'llegar'): 2,
#  ('llegar', 'junto'): 1,
#  ('junto', 'a'): 1,
#  ('a', 'él'): 1,
#  ('él', 'sus'): 1,
#  ('sus', 'ojos'): 1,
#  ('ojos', 'de'): 1,
#  ('un', 'azul'): 1,
#  ('azul', 'profundo'): 1,
#  ('profundo', 'se'): 1,
#  ('se', 'encontraron'): 1,
#  ('encontraron', 'con'): 1,
#  ('los', 'de'): 1,
#  ('de', 'elena'): 1,
#  ('no', 'deberías'): 1,
#  ('deberías', 'estar'): 1,
#  ('estar', 'aquí'): 1,
#  ('aquí', 'dijo'): 1,
#  ('dijo', 'el'): 1,
#  ('niño', 'con'): 1,
#  ('una', 'voz'): 1,
#  ('voz', 'suave'): 1,
#  ('suave', 'casi'): 1,
#  ('casi', 'susurrante'): 1,
#  ('susurrante', 'elena'): 1,
#  ('elena', 'sintió'): 1,
#  ('sintió', 'un'): 1,
#  ('un', 'escalofrío'): 1,
#  ('escalofrío', 'recorrer'): 1,
#  ('recorrer', 'su'): 1,
#  ('su', 'espalda'): 1,
#  ('espalda', 'pero'): 1,
#  ('pero', 'antes'): 1,
#  ('antes', 'de'): 1,
#  ('de', 'poder'): 1,
#  ('poder', 'responder'): 1,
#  ('responder', 'la'): 1,
#  ('la', 'figura'): 1,
#  ('figura', 'desapareció'): 1,
#  ('desapareció', 'en'): 1,
#  ('el', 'aire'): 1,
#  ('aire', 'como'): 1,
#  ('si', 'nunca'): 1,
#  ('nunca', 'hubiera'): 1,
#  ('hubiera', 'estado'): 1,
#  ('estado', 'allí'): 1,
#  ('allí', 'confusa'): 1,
#  ('confusa', 'y'): 1,
#  ('y', 'con'): 1,
#  ('con', 'el'): 2,
#  ('el', 'corazón'): 1,
#  ('corazón', 'acelerado'): 1,
#  ('acelerado', 'miró'): 1,
#  ('miró', 'a'): 1,
#  ('alrededor', 'pero'): 1,
#  ('pero', 'el'): 2,
#  ('bosque', 'estaba'): 1,
#  ('estaba', 'desierto'): 1,
#  ('desierto', 'decidió'): 1,
#  ('decidió', 'regresar'): 1,
#  ('regresar', 'al'): 1,
#  ('al', 'pueblo'): 2,
#  ('pueblo', 'pero'): 1,
#  ('el', 'camino'): 1,
#  ('camino', 'que'): 1,
#  ('que', 'había'): 2,
#  ('había', 'tomado'): 1,
#  ('tomado', 'parecía'): 1,
#  ('parecía', 'haber'): 1,
#  ('haber', 'cambiado'): 1,
#  ('cambiado', 'las'): 2,
#  ('las', 'mismas'): 1,
#  ('mismas', 'rutas'): 1,
#  ('rutas', 'que'): 1,
#  ('que', 'antes'): 1,
#  ('antes', 'le'): 1,
#  ('le', 'resultaban'): 1,
#  ('resultaban', 'familiares'): 1,
#  ('familiares', 'ahora'): 1,
#  ('ahora', 'parecían'): 1,
#  ('parecían', 'distorsionadas'): 1,
#  ('distorsionadas', 'llevándola'): 1,
#  ('llevándola', 'en'): 1,
#  ('en', 'círculos'): 1,
#  ('círculos', 'sin'): 1,
#  ('sin', 'un'): 1,
#  ('un', 'destino'): 1,
#  ('destino', 'claro'): 1,
#  ('claro', 'el'): 1,
#  ('el', 'sol'): 1,
#  ('sol', 'se'): 1,
#  ('se', 'estaba'): 1,
#  ('estaba', 'poniendo'): 1,
#  ('poniendo', 'y'): 1,
#  ('y', 'la'): 1,
#  ('la', 'oscuridad'): 1,
#  ('oscuridad', 'envolvía'): 1,
#  ('lugar', 'cada'): 1,
#  ('cada', 'vez'): 1,
#  ('vez', 'más'): 2,
#  ('más', 'respirando'): 1,
#  ('respirando', 'profundamente'): 1,
#  ('profundamente', 'elena'): 1,
#  ('elena', 'intentó'): 1,
#  ('intentó', 'calmarse'): 1,
#  ('calmarse', 'pero'): 1,
#  ('pero', 'no'): 1,
#  ('no', 'podía'): 1,
#  ('podía', 'dejar'): 1,
#  ('dejar', 'de'): 1,
#  ('de', 'pensar'): 1,
#  ('pensar', 'en'): 1,
#  ('en', 'las'): 1,
#  ('las', 'palabras'): 1,
#  ('palabras', 'del'): 1,
#  ('del', 'niño'): 1,
#  ('niño', 'finalmente'): 1,
#  ('finalmente', 'después'): 1,
#  ('después', 'de'): 1,
#  ('de', 'lo'): 1,
#  ('lo', 'que'): 1,
#  ('que', 'le'): 1,
#  ('le', 'pareció'): 1,
#  ('pareció', 'una'): 1,
#  ('una', 'eternidad'): 1,
#  ('eternidad', 'encontró'): 1,
#  ('encontró', 'la'): 1,
#  ('la', 'salida'): 1,
#  ('salida', 'al'): 1,
#  ('llegar', 'al'): 1,
#  ('pueblo', 'notó'): 1,
#  ('notó', 'que'): 1,
#  ('que', 'algo'): 1,
#  ('algo', 'había'): 1,
#  ('había', 'cambiado'): 1,
#  ('las', 'casas'): 1,
#  ('casas', 'lucían'): 1,
#  ('lucían', 'más'): 1,
#  ('más', 'deterioradas'): 1,
#  ('deterioradas', 'como'): 1,
#  ('si', 'hubieran'): 1,
#  ('hubieran', 'pasado'): 1,
#  ('pasado', 'años'): 1,
#  ('años', 'desde'): 1,
#  ('desde', 'que'): 1,
#  ('que', 'las'): 1,
#  ('las', 'había'): 1,
#  ('había', 'visto'): 1,
#  ('visto', 'por'): 1,
#  ('por', 'última'): 1,
#  ('última', 'vez'): 1,
#  ('vez', 'al'): 1,
#  ('al', 'preguntar'): 1,
#  ('preguntar', 'a'): 1,
#  ('a', 'los'): 1,
#  ('los', 'aldeanos'): 1,
#  ('aldeanos', 'descubrió'): 1,
#  ('descubrió', 'con'): 1,
#  ('con', 'horror'): 1,
#  ('horror', 'que'): 1,
#  ('había', 'desaparecido'): 1,
#  ('desaparecido', 'por'): 1,
#  ('por', 'tres'): 1,
#  ('tres', 'días'): 1,
#  ('días', 'aunque'): 1,
#  ('aunque', 'para'): 1,
#  ('para', 'ella'): 1,
#  ('ella', 'solo'): 1,
#  ('solo', 'había'): 1,
#  ('había', 'pasado'): 1,
#  ('pasado', 'una'): 1,
#  ('una', 'tarde'): 1,
#  ('tarde', 'el'): 1,
#  ('encantado', 'había'): 1,
#  ('había', 'jugado'): 1,
#  ('jugado', 'con'): 1,
#  ('el', 'tiempo'): 1,
#  ('tiempo', 'una'): 1,
#  ('una', 'vez'): 1,
#  ('más', 'dejando'): 1,
#  ('dejando', 'a'): 1,
#  ('elena', 'con'): 1,
#  ('con', 'más'): 1,
#  ('más', 'preguntas'): 1,
#  ('preguntas', 'que'): 1,
#  ('que', 'respuestas'): 1,
#  ('respuestas', 'y'): 1,
#  ('y', 'una'): 1,
#  ('una', 'advertencia'): 1,
#  ('advertencia', 'clara'): 1,
#  ('clara', 'en'): 1,
#  ('en', 'su'): 1,
#  ('su', 'mente'): 1,
#  ('mente', 'nunca'): 1,
#  ('nunca', 'volvería'): 1,
#  ('volvería', 'a'): 1,
#  ('a', 'entrar'): 1}

# %%
trigrams
# Out:
# {('el', 'misterio', 'del'): 1,
#  ('misterio', 'del', 'bosque'): 1,
#  ('del', 'bosque', 'encantado'): 1,
#  ('bosque', 'encantado', 'una'): 1,
#  ('encantado', 'una', 'fría'): 1,
#  ('una', 'fría', 'tarde'): 1,
#  ('fría', 'tarde', 'de'): 1,
#  ('tarde', 'de', 'otoño'): 1,
#  ('de', 'otoño', 'elena'): 1,
#  ('otoño', 'elena', 'decidió'): 1,
#  ('elena', 'decidió', 'explorar'): 1,
#  ('decidió', 'explorar', 'el'): 1,
#  ('explorar', 'el', 'viejo'): 1,
#  ('el', 'viejo', 'bosque'): 1,
#  ('viejo', 'bosque', 'que'): 1,
#  ('bosque', 'que', 'se'): 1,
#  ('que', 'se', 'encontraba'): 1,
#  ('se', 'encontraba', 'a'): 1,
#  ('encontraba', 'a', 'las'): 1,
#  ('a', 'las', 'afueras'): 1,
#  ('las', 'afueras', 'del'): 1,
#  ('afueras', 'del', 'pueblo'): 1,
#  ('del', 'pueblo', 'la'): 1,
#  ('pueblo', 'la', 'gente'): 1,
#  ('la', 'gente', 'solía'): 1,
#  ('gente', 'solía', 'decir'): 1,
#  ('solía', 'decir', 'que'): 1,
#  ('decir', 'que', 'aquel'): 1,
#  ('que', 'aquel', 'lugar'): 1,
#  ('aquel', 'lugar', 'estaba'): 1,
#  ('lugar', 'estaba', 'maldito'): 1,
#  ('estaba', 'maldito', 'que'): 1,
#  ('maldito', 'que', 'quienes'): 1,
#  ('que', 'quienes', 'se'): 1,
#  ('quienes', 'se', 'aventuraban'): 1,
#  ('se', 'aventuraban', 'demasiado'): 1,
#  ('aventuraban', 'demasiado', 'en'): 1,
#  ('demasiado', 'en', 'sus'): 1,
#  ('en', 'sus', 'profundidades'): 1,
#  ('sus', 'profundidades', 'no'): 1,
#  ('profundidades', 'no', 'regresaban'): 1,
#  ('no', 'regresaban', 'jamás'): 1,
#  ('regresaban', 'jamás', 'pero'): 1,
#  ('jamás', 'pero', 'a'): 1,
#  ('pero', 'a', 'elena'): 1,
#  ('a', 'elena', 'no'): 1,
#  ('elena', 'no', 'le'): 1,
#  ('no', 'le', 'importaban'): 1,
#  ('le', 'importaban', 'esas'): 1,
#  ('importaban', 'esas', 'historias'): 1,
#  ('esas', 'historias', 'tenía'): 1,
#  ('historias', 'tenía', 'una'): 1,
#  ('tenía', 'una', 'curiosidad'): 1,
#  ('una', 'curiosidad', 'insaciable'): 1,
#  ('curiosidad', 'insaciable', 'y'): 1,
#  ('insaciable', 'y', 'un'): 1,
#  ('y', 'un', 'espíritu'): 1,
#  ('un', 'espíritu', 'aventurero'): 1,
#  ('espíritu', 'aventurero', 'que'): 1,
#  ('aventurero', 'que', 'no'): 1,
#  ('que', 'no', 'conocía'): 1,
#  ('no', 'conocía', 'el'): 1,
#  ('conocía', 'el', 'miedo'): 1,
#  ('el', 'miedo', 'al'): 1,
#  ('miedo', 'al', 'adentrarse'): 1,
#  ('al', 'adentrarse', 'en'): 1,
#  ('adentrarse', 'en', 'el'): 1,
#  ('en', 'el', 'bosque'): 1,
#  ('el', 'bosque', 'la'): 1,
#  ('bosque', 'la', 'luz'): 1,
#  ('la', 'luz', 'del'): 1,
#  ('luz', 'del', 'sol'): 1,
#  ('del', 'sol', 'comenzó'): 1,
#  ('sol', 'comenzó', 'a'): 1,
#  ('comenzó', 'a', 'desvanecerse'): 1,
#  ('a', 'desvanecerse', 'entre'): 1,
#  ('desvanecerse', 'entre', 'los'): 1,
#  ('entre', 'los', 'árboles'): 1,
#  ('los', 'árboles', 'creando'): 1,
#  ('árboles', 'creando', 'sombras'): 1,
#  ('creando', 'sombras', 'alargadas'): 1,
#  ('sombras', 'alargadas', 'que'): 1,
#  ('alargadas', 'que', 'parecían'): 1,
#  ('que', 'parecían', 'moverse'): 1,
#  ('parecían', 'moverse', 'a'): 1,
#  ('moverse', 'a', 'su'): 1,
#  ('a', 'su', 'alrededor'): 2,
#  ('su', 'alrededor', 'a'): 1,
#  ('alrededor', 'a', 'cada'): 1,
#  ('a', 'cada', 'paso'): 1,
#  ('cada', 'paso', 'las'): 1,
#  ('paso', 'las', 'hojas'): 1,
#  ('las', 'hojas', 'secas'): 1,
#  ('hojas', 'secas', 'crujían'): 1,
#  ('secas', 'crujían', 'bajo'): 1,
#  ('crujían', 'bajo', 'sus'): 1,
#  ('bajo', 'sus', 'botas'): 1,
#  ('sus', 'botas', 'resonando'): 1,
#  ('botas', 'resonando', 'en'): 1,
#  ('resonando', 'en', 'la'): 1,
#  ('en', 'la', 'inquietante'): 1,
#  ('la', 'inquietante', 'tranquilidad'): 1,
#  ('inquietante', 'tranquilidad', 'que'): 1,
#  ('tranquilidad', 'que', 'envolvía'): 1,
#  ('que', 'envolvía', 'el'): 1,
#  ('envolvía', 'el', 'lugar'): 2,
#  ('el', 'lugar', 'todo'): 1,
#  ('lugar', 'todo', 'estaba'): 1,
#  ('todo', 'estaba', 'en'): 1,
#  ('estaba', 'en', 'silencio'): 1,
#  ('en', 'silencio', 'excepto'): 1,
#  ('silencio', 'excepto', 'por'): 1,
#  ('excepto', 'por', 'el'): 1,
#  ('por', 'el', 'ocasional'): 1,
#  ('el', 'ocasional', 'canto'): 1,
#  ('ocasional', 'canto', 'de'): 1,
#  ('canto', 'de', 'un'): 1,
#  ('de', 'un', 'cuervo'): 1,
#  ('un', 'cuervo', 'en'): 1,
#  ('cuervo', 'en', 'lo'): 1,
#  ('en', 'lo', 'alto'): 1,
#  ('lo', 'alto', 'de'): 1,
#  ('alto', 'de', 'repente'): 1,
#  ('de', 'repente', 'a'): 1,
#  ('repente', 'a', 'lo'): 1,
#  ('a', 'lo', 'lejos'): 1,
#  ('lo', 'lejos', 'divisó'): 1,
#  ('lejos', 'divisó', 'una'): 1,
#  ('divisó', 'una', 'figura'): 1,
#  ('una', 'figura', 'parecía'): 1,
#  ('figura', 'parecía', 'un'): 1,
#  ('parecía', 'un', 'niño'): 1,
#  ('un', 'niño', 'inmóvil'): 1,
#  ('niño', 'inmóvil', 'con'): 1,
#  ('inmóvil', 'con', 'una'): 1,
#  ('con', 'una', 'capa'): 1,
#  ('una', 'capa', 'oscura'): 1,
#  ('capa', 'oscura', 'que'): 1,
#  ('oscura', 'que', 'se'): 1,
#  ('que', 'se', 'confundía'): 1,
#  ('se', 'confundía', 'con'): 1,
#  ('confundía', 'con', 'los'): 1,
#  ('con', 'los', 'troncos'): 1,
#  ('los', 'troncos', 'de'): 1,
#  ('troncos', 'de', 'los'): 1,
#  ('de', 'los', 'árboles'): 1,
#  ('los', 'árboles', 'elena'): 1,
#  ('árboles', 'elena', 'intrigada'): 1,
#  ('elena', 'intrigada', 'decidió'): 1,
#  ('intrigada', 'decidió', 'acercarse'): 1,
#  ('decidió', 'acercarse', 'cuanto'): 1,
#  ('acercarse', 'cuanto', 'más'): 1,
#  ('cuanto', 'más', 'se'): 1,
#  ('más', 'se', 'aproximaba'): 1,
#  ('se', 'aproximaba', 'más'): 1,
#  ('aproximaba', 'más', 'claro'): 1,
#  ('más', 'claro', 'veía'): 1,
#  ('claro', 'veía', 'que'): 1,
#  ('veía', 'que', 'el'): 1,
#  ('que', 'el', 'niño'): 1,
#  ('el', 'niño', 'no'): 1,
#  ('niño', 'no', 'parecía'): 1,
#  ('no', 'parecía', 'estar'): 1,
#  ('parecía', 'estar', 'del'): 1,
#  ('estar', 'del', 'todo'): 1,
#  ('del', 'todo', 'presente'): 1,
#  ('todo', 'presente', 'como'): 1,
#  ('presente', 'como', 'si'): 1,
#  ('como', 'si', 'fuera'): 1,
#  ('si', 'fuera', 'parte'): 1,
#  ('fuera', 'parte', 'del'): 1,
#  ('parte', 'del', 'mismo'): 1,
#  ('del', 'mismo', 'bosque'): 1,
#  ('mismo', 'bosque', 'una'): 1,
#  ('bosque', 'una', 'extensión'): 1,
#  ('una', 'extensión', 'más'): 1,
#  ('extensión', 'más', 'de'): 1,
#  ('más', 'de', 'sus'): 1,
#  ('de', 'sus', 'secretos'): 1,
#  ('sus', 'secretos', 'al'): 1,
#  ('secretos', 'al', 'llegar'): 1,
#  ('al', 'llegar', 'junto'): 1,
#  ('llegar', 'junto', 'a'): 1,
#  ('junto', 'a', 'él'): 1,
#  ('a', 'él', 'sus'): 1,
#  ('él', 'sus', 'ojos'): 1,
#  ('sus', 'ojos', 'de'): 1,
#  ('ojos', 'de', 'un'): 1,
#  ('de', 'un', 'azul'): 1,
#  ('un', 'azul', 'profundo'): 1,
#  ('azul', 'profundo', 'se'): 1,
#  ('profundo', 'se', 'encontraron'): 1,
#  ('se', 'encontraron', 'con'): 1,
#  ('encontraron', 'con', 'los'): 1,
#  ('con', 'los', 'de'): 1,
#  ('los', 'de', 'elena'): 1,
#  ('de', 'elena', 'no'): 1,
#  ('elena', 'no', 'deberías'): 1,
#  ('no', 'deberías', 'estar'): 1,
#  ('deberías', 'estar', 'aquí'): 1,
#  ('estar', 'aquí', 'dijo'): 1,
#  ('aquí', 'dijo', 'el'): 1,
#  ('dijo', 'el', 'niño'): 1,
#  ('el', 'niño', 'con'): 1,
#  ('niño', 'con', 'una'): 1,
#  ('con', 'una', 'voz'): 1,
#  ('una', 'voz', 'suave'): 1,
#  ('voz', 'suave', 'casi'): 1,
#  ('suave', 'casi', 'susurrante'): 1,
#  ('casi', 'susurrante', 'elena'): 1,
#  ('susurrante', 'elena', 'sintió'): 1,
#  ('elena', 'sintió', 'un'): 1,
#  ('sintió', 'un', 'escalofrío'): 1,
#  ('un', 'escalofrío', 'recorrer'): 1,
#  ('escalofrío', 'recorrer', 'su'): 1,
#  ('recorrer', 'su', 'espalda'): 1,
#  ('su', 'espalda', 'pero'): 1,
#  ('espalda', 'pero', 'antes'): 1,
#  ('pero', 'antes', 'de'): 1,
#  ('antes', 'de', 'poder'): 1,
#  ('de', 'poder', 'responder'): 1,
#  ('poder', 'responder', 'la'): 1,
#  ('responder', 'la', 'figura'): 1,
#  ('la', 'figura', 'desapareció'): 1,
#  ('figura', 'desapareció', 'en'): 1,
#  ('desapareció', 'en', 'el'): 1,
#  ('en', 'el', 'aire'): 1,
#  ('el', 'aire', 'como'): 1,
#  ('aire', 'como', 'si'): 1,
#  ('como', 'si', 'nunca'): 1,
#  ('si', 'nunca', 'hubiera'): 1,
#  ('nunca', 'hubiera', 'estado'): 1,
#  ('hubiera', 'estado', 'allí'): 1,
#  ('estado', 'allí', 'confusa'): 1,
#  ('allí', 'confusa', 'y'): 1,
#  ('confusa', 'y', 'con'): 1,
#  ('y', 'con', 'el'): 1,
#  ('con', 'el', 'corazón'): 1,
#  ('el', 'corazón', 'acelerado'): 1,
#  ('corazón', 'acelerado', 'miró'): 1,
#  ('acelerado', 'miró', 'a'): 1,
#  ('miró', 'a', 'su'): 1,
#  ('su', 'alrededor', 'pero'): 1,
#  ('alrededor', 'pero', 'el'): 1,
#  ('pero', 'el', 'bosque'): 1,
#  ('el', 'bosque', 'estaba'): 1,
#  ('bosque', 'estaba', 'desierto'): 1,
#  ('estaba', 'desierto', 'decidió'): 1,
#  ('desierto', 'decidió', 'regresar'): 1,
#  ('decidió', 'regresar', 'al'): 1,
#  ('regresar', 'al', 'pueblo'): 1,
#  ('al', 'pueblo', 'pero'): 1,
#  ('pueblo', 'pero', 'el'): 1,
#  ('pero', 'el', 'camino'): 1,
#  ('el', 'camino', 'que'): 1,
#  ('camino', 'que', 'había'): 1,
#  ('que', 'había', 'tomado'): 1,
#  ('había', 'tomado', 'parecía'): 1,
#  ('tomado', 'parecía', 'haber'): 1,
#  ('parecía', 'haber', 'cambiado'): 1,
#  ('haber', 'cambiado', 'las'): 1,
#  ('cambiado', 'las', 'mismas'): 1,
#  ('las', 'mismas', 'rutas'): 1,
#  ('mismas', 'rutas', 'que'): 1,
#  ('rutas', 'que', 'antes'): 1,
#  ('que', 'antes', 'le'): 1,
#  ('antes', 'le', 'resultaban'): 1,
#  ('le', 'resultaban', 'familiares'): 1,
#  ('resultaban', 'familiares', 'ahora'): 1,
#  ('familiares', 'ahora', 'parecían'): 1,
#  ('ahora', 'parecían', 'distorsionadas'): 1,
#  ('parecían', 'distorsionadas', 'llevándola'): 1,
#  ('distorsionadas', 'llevándola', 'en'): 1,
#  ('llevándola', 'en', 'círculos'): 1,
#  ('en', 'círculos', 'sin'): 1,
#  ('círculos', 'sin', 'un'): 1,
#  ('sin', 'un', 'destino'): 1,
#  ('un', 'destino', 'claro'): 1,
#  ('destino', 'claro', 'el'): 1,
#  ('claro', 'el', 'sol'): 1,
#  ('el', 'sol', 'se'): 1,
#  ('sol', 'se', 'estaba'): 1,
#  ('se', 'estaba', 'poniendo'): 1,
#  ('estaba', 'poniendo', 'y'): 1,
#  ('poniendo', 'y', 'la'): 1,
#  ('y', 'la', 'oscuridad'): 1,
#  ('la', 'oscuridad', 'envolvía'): 1,
#  ('oscuridad', 'envolvía', 'el'): 1,
#  ('el', 'lugar', 'cada'): 1,
#  ('lugar', 'cada', 'vez'): 1,
#  ('cada', 'vez', 'más'): 1,
#  ('vez', 'más', 'respirando'): 1,
#  ('más', 'respirando', 'profundamente'): 1,
#  ('respirando', 'profundamente', 'elena'): 1,
#  ('profundamente', 'elena', 'intentó'): 1,
#  ('elena', 'intentó', 'calmarse'): 1,
#  ('intentó', 'calmarse', 'pero'): 1,
#  ('calmarse', 'pero', 'no'): 1,
#  ('pero', 'no', 'podía'): 1,
#  ('no', 'podía', 'dejar'): 1,
#  ('podía', 'dejar', 'de'): 1,
#  ('dejar', 'de', 'pensar'): 1,
#  ('de', 'pensar', 'en'): 1,
#  ('pensar', 'en', 'las'): 1,
#  ('en', 'las', 'palabras'): 1,
#  ('las', 'palabras', 'del'): 1,
#  ('palabras', 'del', 'niño'): 1,
#  ('del', 'niño', 'finalmente'): 1,
#  ('niño', 'finalmente', 'después'): 1,
#  ('finalmente', 'después', 'de'): 1,
#  ('después', 'de', 'lo'): 1,
#  ('de', 'lo', 'que'): 1,
#  ('lo', 'que', 'le'): 1,
#  ('que', 'le', 'pareció'): 1,
#  ('le', 'pareció', 'una'): 1,
#  ('pareció', 'una', 'eternidad'): 1,
#  ('una', 'eternidad', 'encontró'): 1,
#  ('eternidad', 'encontró', 'la'): 1,
#  ('encontró', 'la', 'salida'): 1,
#  ('la', 'salida', 'al'): 1,
#  ('salida', 'al', 'llegar'): 1,
#  ('al', 'llegar', 'al'): 1,
#  ('llegar', 'al', 'pueblo'): 1,
#  ('al', 'pueblo', 'notó'): 1,
#  ('pueblo', 'notó', 'que'): 1,
#  ('notó', 'que', 'algo'): 1,
#  ('que', 'algo', 'había'): 1,
#  ('algo', 'había', 'cambiado'): 1,
#  ('había', 'cambiado', 'las'): 1,
#  ('cambiado', 'las', 'casas'): 1,
#  ('las', 'casas', 'lucían'): 1,
#  ('casas', 'lucían', 'más'): 1,
#  ('lucían', 'más', 'deterioradas'): 1,
#  ('más', 'deterioradas', 'como'): 1,
#  ('deterioradas', 'como', 'si'): 1,
#  ('como', 'si', 'hubieran'): 1,
#  ('si', 'hubieran', 'pasado'): 1,
#  ('hubieran', 'pasado', 'años'): 1,
#  ('pasado', 'años', 'desde'): 1,
#  ('años', 'desde', 'que'): 1,
#  ('desde', 'que', 'las'): 1,
#  ('que', 'las', 'había'): 1,
#  ('las', 'había', 'visto'): 1,
#  ('había', 'visto', 'por'): 1,
#  ('visto', 'por', 'última'): 1,
#  ('por', 'última', 'vez'): 1,
#  ('última', 'vez', 'al'): 1,
#  ('vez', 'al', 'preguntar'): 1,
#  ('al', 'preguntar', 'a'): 1,
#  ('preguntar', 'a', 'los'): 1,
#  ('a', 'los', 'aldeanos'): 1,
#  ('los', 'aldeanos', 'descubrió'): 1,
#  ('aldeanos', 'descubrió', 'con'): 1,
#  ('descubrió', 'con', 'horror'): 1,
#  ('con', 'horror', 'que'): 1,
#  ('horror', 'que', 'había'): 1,
#  ('que', 'había', 'desaparecido'): 1,
#  ('había', 'desaparecido', 'por'): 1,
#  ('desaparecido', 'por', 'tres'): 1,
#  ('por', 'tres', 'días'): 1,
#  ('tres', 'días', 'aunque'): 1,
#  ('días', 'aunque', 'para'): 1,
#  ('aunque', 'para', 'ella'): 1,
#  ('para', 'ella', 'solo'): 1,
#  ('ella', 'solo', 'había'): 1,
#  ('solo', 'había', 'pasado'): 1,
#  ('había', 'pasado', 'una'): 1,
#  ('pasado', 'una', 'tarde'): 1,
#  ('una', 'tarde', 'el'): 1,
#  ('tarde', 'el', 'bosque'): 1,
#  ('el', 'bosque', 'encantado'): 1,
#  ('bosque', 'encantado', 'había'): 1,
#  ('encantado', 'había', 'jugado'): 1,
#  ('había', 'jugado', 'con'): 1,
#  ('jugado', 'con', 'el'): 1,
#  ('con', 'el', 'tiempo'): 1,
#  ('el', 'tiempo', 'una'): 1,
#  ('tiempo', 'una', 'vez'): 1,
#  ('una', 'vez', 'más'): 1,
#  ('vez', 'más', 'dejando'): 1,
#  ('más', 'dejando', 'a'): 1,
#  ('dejando', 'a', 'elena'): 1,
#  ('a', 'elena', 'con'): 1,
#  ('elena', 'con', 'más'): 1,
#  ('con', 'más', 'preguntas'): 1,
#  ('más', 'preguntas', 'que'): 1,
#  ('preguntas', 'que', 'respuestas'): 1,
#  ('que', 'respuestas', 'y'): 1,
#  ('respuestas', 'y', 'una'): 1,
#  ('y', 'una', 'advertencia'): 1,
#  ('una', 'advertencia', 'clara'): 1,
#  ('advertencia', 'clara', 'en'): 1,
#  ('clara', 'en', 'su'): 1,
#  ('en', 'su', 'mente'): 1,
#  ('su', 'mente', 'nunca'): 1,
#  ('mente', 'nunca', 'volvería'): 1,
#  ('nunca', 'volvería', 'a'): 1,
#  ('volvería', 'a', 'entrar'): 1}

# %%
cuatrigrams
# Out:
# {('el', 'misterio', 'del', 'bosque'): 1,
#  ('misterio', 'del', 'bosque', 'encantado'): 1,
#  ('del', 'bosque', 'encantado', 'una'): 1,
#  ('bosque', 'encantado', 'una', 'fría'): 1,
#  ('encantado', 'una', 'fría', 'tarde'): 1,
#  ('una', 'fría', 'tarde', 'de'): 1,
#  ('fría', 'tarde', 'de', 'otoño'): 1,
#  ('tarde', 'de', 'otoño', 'elena'): 1,
#  ('de', 'otoño', 'elena', 'decidió'): 1,
#  ('otoño', 'elena', 'decidió', 'explorar'): 1,
#  ('elena', 'decidió', 'explorar', 'el'): 1,
#  ('decidió', 'explorar', 'el', 'viejo'): 1,
#  ('explorar', 'el', 'viejo', 'bosque'): 1,
#  ('el', 'viejo', 'bosque', 'que'): 1,
#  ('viejo', 'bosque', 'que', 'se'): 1,
#  ('bosque', 'que', 'se', 'encontraba'): 1,
#  ('que', 'se', 'encontraba', 'a'): 1,
#  ('se', 'encontraba', 'a', 'las'): 1,
#  ('encontraba', 'a', 'las', 'afueras'): 1,
#  ('a', 'las', 'afueras', 'del'): 1,
#  ('las', 'afueras', 'del', 'pueblo'): 1,
#  ('afueras', 'del', 'pueblo', 'la'): 1,
#  ('del', 'pueblo', 'la', 'gente'): 1,
#  ('pueblo', 'la', 'gente', 'solía'): 1,
#  ('la', 'gente', 'solía', 'decir'): 1,
#  ('gente', 'solía', 'decir', 'que'): 1,
#  ('solía', 'decir', 'que', 'aquel'): 1,
#  ('decir', 'que', 'aquel', 'lugar'): 1,
#  ('que', 'aquel', 'lugar', 'estaba'): 1,
#  ('aquel', 'lugar', 'estaba', 'maldito'): 1,
#  ('lugar', 'estaba', 'maldito', 'que'): 1,
#  ('estaba', 'maldito', 'que', 'quienes'): 1,
#  ('maldito', 'que', 'quienes', 'se'): 1,
#  ('que', 'quienes', 'se', 'aventuraban'): 1,
#  ('quienes', 'se', 'aventuraban', 'demasiado'): 1,
#  ('se', 'aventuraban', 'demasiado', 'en'): 1,
#  ('aventuraban', 'demasiado', 'en', 'sus'): 1,
#  ('demasiado', 'en', 'sus', 'profundidades'): 1,
#  ('en', 'sus', 'profundidades', 'no'): 1,
#  ('sus', 'profundidades', 'no', 'regresaban'): 1,
#  ('profundidades', 'no', 'regresaban', 'jamás'): 1,
#  ('no', 'regresaban', 'jamás', 'pero'): 1,
#  ('regresaban', 'jamás', 'pero', 'a'): 1,
#  ('jamás', 'pero', 'a', 'elena'): 1,
#  ('pero', 'a', 'elena', 'no'): 1,
#  ('a', 'elena', 'no', 'le'): 1,
#  ('elena', 'no', 'le', 'importaban'): 1,
#  ('no', 'le', 'importaban', 'esas'): 1,
#  ('le', 'importaban', 'esas', 'historias'): 1,
#  ('importaban', 'esas', 'historias', 'tenía'): 1,
#  ('esas', 'historias', 'tenía', 'una'): 1,
#  ('historias', 'tenía', 'una', 'curiosidad'): 1,
#  ('tenía', 'una', 'curiosidad', 'insaciable'): 1,
#  ('una', 'curiosidad', 'insaciable', 'y'): 1,
#  ('curiosidad', 'insaciable', 'y', 'un'): 1,
#  ('insaciable', 'y', 'un', 'espíritu'): 1,
#  ('y', 'un', 'espíritu', 'aventurero'): 1,
#  ('un', 'espíritu', 'aventurero', 'que'): 1,
#  ('espíritu', 'aventurero', 'que', 'no'): 1,
#  ('aventurero', 'que', 'no', 'conocía'): 1,
#  ('que', 'no', 'conocía', 'el'): 1,
#  ('no', 'conocía', 'el', 'miedo'): 1,
#  ('conocía', 'el', 'miedo', 'al'): 1,
#  ('el', 'miedo', 'al', 'adentrarse'): 1,
#  ('miedo', 'al', 'adentrarse', 'en'): 1,
#  ('al', 'adentrarse', 'en', 'el'): 1,
#  ('adentrarse', 'en', 'el', 'bosque'): 1,
#  ('en', 'el', 'bosque', 'la'): 1,
#  ('el', 'bosque', 'la', 'luz'): 1,
#  ('bosque', 'la', 'luz', 'del'): 1,
#  ('la', 'luz', 'del', 'sol'): 1,
#  ('luz', 'del', 'sol', 'comenzó'): 1,
#  ('del', 'sol', 'comenzó', 'a'): 1,
#  ('sol', 'comenzó', 'a', 'desvanecerse'): 1,
#  ('comenzó', 'a', 'desvanecerse', 'entre'): 1,
#  ('a', 'desvanecerse', 'entre', 'los'): 1,
#  ('desvanecerse', 'entre', 'los', 'árboles'): 1,
#  ('entre', 'los', 'árboles', 'creando'): 1,
#  ('los', 'árboles', 'creando', 'sombras'): 1,
#  ('árboles', 'creando', 'sombras', 'alargadas'): 1,
#  ('creando', 'sombras', 'alargadas', 'que'): 1,
#  ('sombras', 'alargadas', 'que', 'parecían'): 1,
#  ('alargadas', 'que', 'parecían', 'moverse'): 1,
#  ('que', 'parecían', 'moverse', 'a'): 1,
#  ('parecían', 'moverse', 'a', 'su'): 1,
#  ('moverse', 'a', 'su', 'alrededor'): 1,
#  ('a', 'su', 'alrededor', 'a'): 1,
#  ('su', 'alrededor', 'a', 'cada'): 1,
#  ('alrededor', 'a', 'cada', 'paso'): 1,
#  ('a', 'cada', 'paso', 'las'): 1,
#  ('cada', 'paso', 'las', 'hojas'): 1,
#  ('paso', 'las', 'hojas', 'secas'): 1,
#  ('las', 'hojas', 'secas', 'crujían'): 1,
#  ('hojas', 'secas', 'crujían', 'bajo'): 1,
#  ('secas', 'crujían', 'bajo', 'sus'): 1,
#  ('crujían', 'bajo', 'sus', 'botas'): 1,
#  ('bajo', 'sus', 'botas', 'resonando'): 1,
#  ('sus', 'botas', 'resonando', 'en'): 1,
#  ('botas', 'resonando', 'en', 'la'): 1,
#  ('resonando', 'en', 'la', 'inquietante'): 1,
#  ('en', 'la', 'inquietante', 'tranquilidad'): 1,
#  ('la', 'inquietante', 'tranquilidad', 'que'): 1,
#  ('inquietante', 'tranquilidad', 'que', 'envolvía'): 1,
#  ('tranquilidad', 'que', 'envolvía', 'el'): 1,
#  ('que', 'envolvía', 'el', 'lugar'): 1,
#  ('envolvía', 'el', 'lugar', 'todo'): 1,
#  ('el', 'lugar', 'todo', 'estaba'): 1,
#  ('lugar', 'todo', 'estaba', 'en'): 1,
#  ('todo', 'estaba', 'en', 'silencio'): 1,
#  ('estaba', 'en', 'silencio', 'excepto'): 1,
#  ('en', 'silencio', 'excepto', 'por'): 1,
#  ('silencio', 'excepto', 'por', 'el'): 1,
#  ('excepto', 'por', 'el', 'ocasional'): 1,
#  ('por', 'el', 'ocasional', 'canto'): 1,
#  ('el', 'ocasional', 'canto', 'de'): 1,
#  ('ocasional', 'canto', 'de', 'un'): 1,
#  ('canto', 'de', 'un', 'cuervo'): 1,
#  ('de', 'un', 'cuervo', 'en'): 1,
#  ('un', 'cuervo', 'en', 'lo'): 1,
#  ('cuervo', 'en', 'lo', 'alto'): 1,
#  ('en', 'lo', 'alto', 'de'): 1,
#  ('lo', 'alto', 'de', 'repente'): 1,
#  ('alto', 'de', 'repente', 'a'): 1,
#  ('de', 'repente', 'a', 'lo'): 1,
#  ('repente', 'a', 'lo', 'lejos'): 1,
#  ('a', 'lo', 'lejos', 'divisó'): 1,
#  ('lo', 'lejos', 'divisó', 'una'): 1,
#  ('lejos', 'divisó', 'una', 'figura'): 1,
#  ('divisó', 'una', 'figura', 'parecía'): 1,
#  ('una', 'figura', 'parecía', 'un'): 1,
#  ('figura', 'parecía', 'un', 'niño'): 1,
#  ('parecía', 'un', 'niño', 'inmóvil'): 1,
#  ('un', 'niño', 'inmóvil', 'con'): 1,
#  ('niño', 'inmóvil', 'con', 'una'): 1,
#  ('inmóvil', 'con', 'una', 'capa'): 1,
#  ('con', 'una', 'capa', 'oscura'): 1,
#  ('una', 'capa', 'oscura', 'que'): 1,
#  ('capa', 'oscura', 'que', 'se'): 1,
#  ('oscura', 'que', 'se', 'confundía'): 1,
#  ('que', 'se', 'confundía', 'con'): 1,
#  ('se', 'confundía', 'con', 'los'): 1,
#  ('confundía', 'con', 'los', 'troncos'): 1,
#  ('con', 'los', 'troncos', 'de'): 1,
#  ('los', 'troncos', 'de', 'los'): 1,
#  ('troncos', 'de', 'los', 'árboles'): 1,
#  ('de', 'los', 'árboles', 'elena'): 1,
#  ('los', 'árboles', 'elena', 'intrigada'): 1,
#  ('árboles', 'elena', 'intrigada', 'decidió'): 1,
#  ('elena', 'intrigada', 'decidió', 'acercarse'): 1,
#  ('intrigada', 'decidió', 'acercarse', 'cuanto'): 1,
#  ('decidió', 'acercarse', 'cuanto', 'más'): 1,
#  ('acercarse', 'cuanto', 'más', 'se'): 1,
#  ('cuanto', 'más', 'se', 'aproximaba'): 1,
#  ('más', 'se', 'aproximaba', 'más'): 1,
#  ('se', 'aproximaba', 'más', 'claro'): 1,
#  ('aproximaba', 'más', 'claro', 'veía'): 1,
#  ('más', 'claro', 'veía', 'que'): 1,
#  ('claro', 'veía', 'que', 'el'): 1,
#  ('veía', 'que', 'el', 'niño'): 1,
#  ('que', 'el', 'niño', 'no'): 1,
#  ('el', 'niño', 'no', 'parecía'): 1,
#  ('niño', 'no', 'parecía', 'estar'): 1,
#  ('no', 'parecía', 'estar', 'del'): 1,
#  ('parecía', 'estar', 'del', 'todo'): 1,
#  ('estar', 'del', 'todo', 'presente'): 1,
#  ('del', 'todo', 'presente', 'como'): 1,
#  ('todo', 'presente', 'como', 'si'): 1,
#  ('presente', 'como', 'si', 'fuera'): 1,
#  ('como', 'si', 'fuera', 'parte'): 1,
#  ('si', 'fuera', 'parte', 'del'): 1,
#  ('fuera', 'parte', 'del', 'mismo'): 1,
#  ('parte', 'del', 'mismo', 'bosque'): 1,
#  ('del', 'mismo', 'bosque', 'una'): 1,
#  ('mismo', 'bosque', 'una', 'extensión'): 1,
#  ('bosque', 'una', 'extensión', 'más'): 1,
#  ('una', 'extensión', 'más', 'de'): 1,
#  ('extensión', 'más', 'de', 'sus'): 1,
#  ('más', 'de', 'sus', 'secretos'): 1,
#  ('de', 'sus', 'secretos', 'al'): 1,
#  ('sus', 'secretos', 'al', 'llegar'): 1,
#  ('secretos', 'al', 'llegar', 'junto'): 1,
#  ('al', 'llegar', 'junto', 'a'): 1,
#  ('llegar', 'junto', 'a', 'él'): 1,
#  ('junto', 'a', 'él', 'sus'): 1,
#  ('a', 'él', 'sus', 'ojos'): 1,
#  ('él', 'sus', 'ojos', 'de'): 1,
#  ('sus', 'ojos', 'de', 'un'): 1,
#  ('ojos', 'de', 'un', 'azul'): 1,
#  ('de', 'un', 'azul', 'profundo'): 1,
#  ('un', 'azul', 'profundo', 'se'): 1,
#  ('azul', 'profundo', 'se', 'encontraron'): 1,
#  ('profundo', 'se', 'encontraron', 'con'): 1,
#  ('se', 'encontraron', 'con', 'los'): 1,
#  ('encontraron', 'con', 'los', 'de'): 1,
#  ('con', 'los', 'de', 'elena'): 1,
#  ('los', 'de', 'elena', 'no'): 1,
#  ('de', 'elena', 'no', 'deberías'): 1,
#  ('elena', 'no', 'deberías', 'estar'): 1,
#  ('no', 'deberías', 'estar', 'aquí'): 1,
#  ('deberías', 'estar', 'aquí', 'dijo'): 1,
#  ('estar', 'aquí', 'dijo', 'el'): 1,
#  ('aquí', 'dijo', 'el', 'niño'): 1,
#  ('dijo', 'el', 'niño', 'con'): 1,
#  ('el', 'niño', 'con', 'una'): 1,
#  ('niño', 'con', 'una', 'voz'): 1,
#  ('con', 'una', 'voz', 'suave'): 1,
#  ('una', 'voz', 'suave', 'casi'): 1,
#  ('voz', 'suave', 'casi', 'susurrante'): 1,
#  ('suave', 'casi', 'susurrante', 'elena'): 1,
#  ('casi', 'susurrante', 'elena', 'sintió'): 1,
#  ('susurrante', 'elena', 'sintió', 'un'): 1,
#  ('elena', 'sintió', 'un', 'escalofrío'): 1,
#  ('sintió', 'un', 'escalofrío', 'recorrer'): 1,
#  ('un', 'escalofrío', 'recorrer', 'su'): 1,
#  ('escalofrío', 'recorrer', 'su', 'espalda'): 1,
#  ('recorrer', 'su', 'espalda', 'pero'): 1,
#  ('su', 'espalda', 'pero', 'antes'): 1,
#  ('espalda', 'pero', 'antes', 'de'): 1,
#  ('pero', 'antes', 'de', 'poder'): 1,
#  ('antes', 'de', 'poder', 'responder'): 1,
#  ('de', 'poder', 'responder', 'la'): 1,
#  ('poder', 'responder', 'la', 'figura'): 1,
#  ('responder', 'la', 'figura', 'desapareció'): 1,
#  ('la', 'figura', 'desapareció', 'en'): 1,
#  ('figura', 'desapareció', 'en', 'el'): 1,
#  ('desapareció', 'en', 'el', 'aire'): 1,
#  ('en', 'el', 'aire', 'como'): 1,
#  ('el', 'aire', 'como', 'si'): 1,
#  ('aire', 'como', 'si', 'nunca'): 1,
#  ('como', 'si', 'nunca', 'hubiera'): 1,
#  ('si', 'nunca', 'hubiera', 'estado'): 1,
#  ('nunca', 'hubiera', 'estado', 'allí'): 1,
#  ('hubiera', 'estado', 'allí', 'confusa'): 1,
#  ('estado', 'allí', 'confusa', 'y'): 1,
#  ('allí', 'confusa', 'y', 'con'): 1,
#  ('confusa', 'y', 'con', 'el'): 1,
#  ('y', 'con', 'el', 'corazón'): 1,
#  ('con', 'el', 'corazón', 'acelerado'): 1,
#  ('el', 'corazón', 'acelerado', 'miró'): 1,
#  ('corazón', 'acelerado', 'miró', 'a'): 1,
#  ('acelerado', 'miró', 'a', 'su'): 1,
#  ('miró', 'a', 'su', 'alrededor'): 1,
#  ('a', 'su', 'alrededor', 'pero'): 1,
#  ('su', 'alrededor', 'pero', 'el'): 1,
#  ('alrededor', 'pero', 'el', 'bosque'): 1,
#  ('pero', 'el', 'bosque', 'estaba'): 1,
#  ('el', 'bosque', 'estaba', 'desierto'): 1,
#  ('bosque', 'estaba', 'desierto', 'decidió'): 1,
#  ('estaba', 'desierto', 'decidió', 'regresar'): 1,
#  ('desierto', 'decidió', 'regresar', 'al'): 1,
#  ('decidió', 'regresar', 'al', 'pueblo'): 1,
#  ('regresar', 'al', 'pueblo', 'pero'): 1,
#  ('al', 'pueblo', 'pero', 'el'): 1,
#  ('pueblo', 'pero', 'el', 'camino'): 1,
#  ('pero', 'el', 'camino', 'que'): 1,
#  ('el', 'camino', 'que', 'había'): 1,
#  ('camino', 'que', 'había', 'tomado'): 1,
#  ('que', 'había', 'tomado', 'parecía'): 1,
#  ('había', 'tomado', 'parecía', 'haber'): 1,
#  ('tomado', 'parecía', 'haber', 'cambiado'): 1,
#  ('parecía', 'haber', 'cambiado', 'las'): 1,
#  ('haber', 'cambiado', 'las', 'mismas'): 1,
#  ('cambiado', 'las', 'mismas', 'rutas'): 1,
#  ('las', 'mismas', 'rutas', 'que'): 1,
#  ('mismas', 'rutas', 'que', 'antes'): 1,
#  ('rutas', 'que', 'antes', 'le'): 1,
#  ('que', 'antes', 'le', 'resultaban'): 1,
#  ('antes', 'le', 'resultaban', 'familiares'): 1,
#  ('le', 'resultaban', 'familiares', 'ahora'): 1,
#  ('resultaban', 'familiares', 'ahora', 'parecían'): 1,
#  ('familiares', 'ahora', 'parecían', 'distorsionadas'): 1,
#  ('ahora', 'parecían', 'distorsionadas', 'llevándola'): 1,
#  ('parecían', 'distorsionadas', 'llevándola', 'en'): 1,
#  ('distorsionadas', 'llevándola', 'en', 'círculos'): 1,
#  ('llevándola', 'en', 'círculos', 'sin'): 1,
#  ('en', 'círculos', 'sin', 'un'): 1,
#  ('círculos', 'sin', 'un', 'destino'): 1,
#  ('sin', 'un', 'destino', 'claro'): 1,
#  ('un', 'destino', 'claro', 'el'): 1,
#  ('destino', 'claro', 'el', 'sol'): 1,
#  ('claro', 'el', 'sol', 'se'): 1,
#  ('el', 'sol', 'se', 'estaba'): 1,
#  ('sol', 'se', 'estaba', 'poniendo'): 1,
#  ('se', 'estaba', 'poniendo', 'y'): 1,
#  ('estaba', 'poniendo', 'y', 'la'): 1,
#  ('poniendo', 'y', 'la', 'oscuridad'): 1,
#  ('y', 'la', 'oscuridad', 'envolvía'): 1,
#  ('la', 'oscuridad', 'envolvía', 'el'): 1,
#  ('oscuridad', 'envolvía', 'el', 'lugar'): 1,
#  ('envolvía', 'el', 'lugar', 'cada'): 1,
#  ('el', 'lugar', 'cada', 'vez'): 1,
#  ('lugar', 'cada', 'vez', 'más'): 1,
#  ('cada', 'vez', 'más', 'respirando'): 1,
#  ('vez', 'más', 'respirando', 'profundamente'): 1,
#  ('más', 'respirando', 'profundamente', 'elena'): 1,
#  ('respirando', 'profundamente', 'elena', 'intentó'): 1,
#  ('profundamente', 'elena', 'intentó', 'calmarse'): 1,
#  ('elena', 'intentó', 'calmarse', 'pero'): 1,
#  ('intentó', 'calmarse', 'pero', 'no'): 1,
#  ('calmarse', 'pero', 'no', 'podía'): 1,
#  ('pero', 'no', 'podía', 'dejar'): 1,
#  ('no', 'podía', 'dejar', 'de'): 1,
#  ('podía', 'dejar', 'de', 'pensar'): 1,
#  ('dejar', 'de', 'pensar', 'en'): 1,
#  ('de', 'pensar', 'en', 'las'): 1,
#  ('pensar', 'en', 'las', 'palabras'): 1,
#  ('en', 'las', 'palabras', 'del'): 1,
#  ('las', 'palabras', 'del', 'niño'): 1,
#  ('palabras', 'del', 'niño', 'finalmente'): 1,
#  ('del', 'niño', 'finalmente', 'después'): 1,
#  ('niño', 'finalmente', 'después', 'de'): 1,
#  ('finalmente', 'después', 'de', 'lo'): 1,
#  ('después', 'de', 'lo', 'que'): 1,
#  ('de', 'lo', 'que', 'le'): 1,
#  ('lo', 'que', 'le', 'pareció'): 1,
#  ('que', 'le', 'pareció', 'una'): 1,
#  ('le', 'pareció', 'una', 'eternidad'): 1,
#  ('pareció', 'una', 'eternidad', 'encontró'): 1,
#  ('una', 'eternidad', 'encontró', 'la'): 1,
#  ('eternidad', 'encontró', 'la', 'salida'): 1,
#  ('encontró', 'la', 'salida', 'al'): 1,
#  ('la', 'salida', 'al', 'llegar'): 1,
#  ('salida', 'al', 'llegar', 'al'): 1,
#  ('al', 'llegar', 'al', 'pueblo'): 1,
#  ('llegar', 'al', 'pueblo', 'notó'): 1,
#  ('al', 'pueblo', 'notó', 'que'): 1,
#  ('pueblo', 'notó', 'que', 'algo'): 1,
#  ('notó', 'que', 'algo', 'había'): 1,
#  ('que', 'algo', 'había', 'cambiado'): 1,
#  ('algo', 'había', 'cambiado', 'las'): 1,
#  ('había', 'cambiado', 'las', 'casas'): 1,
#  ('cambiado', 'las', 'casas', 'lucían'): 1,
#  ('las', 'casas', 'lucían', 'más'): 1,
#  ('casas', 'lucían', 'más', 'deterioradas'): 1,
#  ('lucían', 'más', 'deterioradas', 'como'): 1,
#  ('más', 'deterioradas', 'como', 'si'): 1,
#  ('deterioradas', 'como', 'si', 'hubieran'): 1,
#  ('como', 'si', 'hubieran', 'pasado'): 1,
#  ('si', 'hubieran', 'pasado', 'años'): 1,
#  ('hubieran', 'pasado', 'años', 'desde'): 1,
#  ('pasado', 'años', 'desde', 'que'): 1,
#  ('años', 'desde', 'que', 'las'): 1,
#  ('desde', 'que', 'las', 'había'): 1,
#  ('que', 'las', 'había', 'visto'): 1,
#  ('las', 'había', 'visto', 'por'): 1,
#  ('había', 'visto', 'por', 'última'): 1,
#  ('visto', 'por', 'última', 'vez'): 1,
#  ('por', 'última', 'vez', 'al'): 1,
#  ('última', 'vez', 'al', 'preguntar'): 1,
#  ('vez', 'al', 'preguntar', 'a'): 1,
#  ('al', 'preguntar', 'a', 'los'): 1,
#  ('preguntar', 'a', 'los', 'aldeanos'): 1,
#  ('a', 'los', 'aldeanos', 'descubrió'): 1,
#  ('los', 'aldeanos', 'descubrió', 'con'): 1,
#  ('aldeanos', 'descubrió', 'con', 'horror'): 1,
#  ('descubrió', 'con', 'horror', 'que'): 1,
#  ('con', 'horror', 'que', 'había'): 1,
#  ('horror', 'que', 'había', 'desaparecido'): 1,
#  ('que', 'había', 'desaparecido', 'por'): 1,
#  ('había', 'desaparecido', 'por', 'tres'): 1,
#  ('desaparecido', 'por', 'tres', 'días'): 1,
#  ('por', 'tres', 'días', 'aunque'): 1,
#  ('tres', 'días', 'aunque', 'para'): 1,
#  ('días', 'aunque', 'para', 'ella'): 1,
#  ('aunque', 'para', 'ella', 'solo'): 1,
#  ('para', 'ella', 'solo', 'había'): 1,
#  ('ella', 'solo', 'había', 'pasado'): 1,
#  ('solo', 'había', 'pasado', 'una'): 1,
#  ('había', 'pasado', 'una', 'tarde'): 1,
#  ('pasado', 'una', 'tarde', 'el'): 1,
#  ('una', 'tarde', 'el', 'bosque'): 1,
#  ('tarde', 'el', 'bosque', 'encantado'): 1,
#  ('el', 'bosque', 'encantado', 'había'): 1,
#  ('bosque', 'encantado', 'había', 'jugado'): 1,
#  ('encantado', 'había', 'jugado', 'con'): 1,
#  ('había', 'jugado', 'con', 'el'): 1,
#  ('jugado', 'con', 'el', 'tiempo'): 1,
#  ('con', 'el', 'tiempo', 'una'): 1,
#  ('el', 'tiempo', 'una', 'vez'): 1,
#  ('tiempo', 'una', 'vez', 'más'): 1,
#  ('una', 'vez', 'más', 'dejando'): 1,
#  ('vez', 'más', 'dejando', 'a'): 1,
#  ('más', 'dejando', 'a', 'elena'): 1,
#  ('dejando', 'a', 'elena', 'con'): 1,
#  ('a', 'elena', 'con', 'más'): 1,
#  ('elena', 'con', 'más', 'preguntas'): 1,
#  ('con', 'más', 'preguntas', 'que'): 1,
#  ('más', 'preguntas', 'que', 'respuestas'): 1,
#  ('preguntas', 'que', 'respuestas', 'y'): 1,
#  ('que', 'respuestas', 'y', 'una'): 1,
#  ('respuestas', 'y', 'una', 'advertencia'): 1,
#  ('y', 'una', 'advertencia', 'clara'): 1,
#  ('una', 'advertencia', 'clara', 'en'): 1,
#  ('advertencia', 'clara', 'en', 'su'): 1,
#  ('clara', 'en', 'su', 'mente'): 1,
#  ('en', 'su', 'mente', 'nunca'): 1,
#  ('su', 'mente', 'nunca', 'volvería'): 1,
#  ('mente', 'nunca', 'volvería', 'a'): 1,
#  ('nunca', 'volvería', 'a', 'entrar'): 1}

# %% [markdown]
# ### Probabilidades de Unigrama, Bigrama, Trigrama y Cuatrigrama
#
# #### Probabilidad de un Unigrama
#
# La fórmula para calcular la probabilidad de un unigrama \( $P(w_1)$ \) es la siguiente:
#
# $$
# P(w_1) = \frac{\text{frecuencia}(w_1)}{N}
# $$
#
# Donde:
#
# - \( $\text{frecuencia}(w_1)$ \) es el número de veces que la palabra \( $w_1$ \) aparece en el corpus.
# - \( N \) es el número total de ocurrencias de los unigramas
#
# Esta fórmula calcula la probabilidad de que un unigrama \( $w_1$ \) ocurra en el conjunto de datos, basado en su frecuencia relativa.

# %%
# PROBABILIDADES CONDICIONALES USANDO NAIVE BAYES CON SUAVIZADO
def get_prob_unigrams(unigrams: dict) -> dict:
    unigrams_prob = {}
    total_count = sum(unigrams.values())  # Total de ocurrencias de unigramas
    for unigram, freq in unigrams.items():
        unigrams_prob[unigram] = freq / total_count  # P(w) = freq(w) / total unigrams
    return unigrams_prob

# %% [markdown]
# #### Probabilidad de un Bigrama
#
# La fórmula para calcular la probabilidad condicional de un bigrama \( $P(w_2 \mid w_1)$ \) con suavizado de Laplace es la siguiente:
#
# $$
# P(w_2 \mid w_1) = \frac{\text{frecuencia}(w_1, w_2) + \alpha}{\text{frecuencia}(w_1) + \alpha \cdot |V|}
# $$
#
# Donde:
#
# - \( $\text{frecuencia}(w_1, w_2)$ \) es el número de veces que el bigrama \( $(w_1, w_2)$ \) aparece en el corpus.
# - \( $\text{frecuencia}(w_1)$ \) es el número de veces que la palabra \( $w_1$ \) aparece en el corpus.
# - \( $\alpha$ \) es el parámetro de suavizado, comúnmente \( $\alpha = 1$ \) en el suavizado de Laplace.
# - \( $|V|$ \) es el tamaño del vocabulario, es decir, el número de palabras únicas en el corpus.
#
# El suavizado de Laplace ayuda a evitar probabilidades cero para bigramas no observados en el corpus.

# %%
def get_prob_bigrams(bigrams: dict, unigrams: dict, alpha=0.1) -> dict:
    bigrams_prob = {}
    V = len(unigrams)  # Tamaño del vocabulario (suavizado Laplace)
    for bigram, freq in bigrams.items():
        bigrams_prob[bigram] = (freq + alpha) / (unigrams[bigram[0]] + V * alpha)  # P(w2|w1)
    return bigrams_prob

# %% [markdown]
# #### Probabilidad de un Trigrama
#
# La fórmula para calcular la probabilidad condicional de un trigrama \( $P(w_3 \mid w_1, w_2)$ \) usando suavizado de Laplace es la siguiente:
#
# $$
# P(w_3 \mid w_1, w_2) = \frac{\text{frecuencia}(w_1, w_2, w_3) + \alpha}{\text{frecuencia}(w_1, w_2) + \alpha \cdot |V|}
# $$
#
# Donde:
#
# - \( $\text{frecuencia}(w_1, w_2, w_3)$ \) es el número de veces que el trigrama \( $(w_1, w_2, w_3)$ \) aparece en el corpus.
# - \( $\text{frecuencia}(w_1, w_2)$ \) es el número de veces que el bigrama \( $(w_1, w_2)$ \) aparece en el corpus.
# - \( $\alpha$ \) es el parámetro de suavizado.
# - \( $|V|$ \) es el tamaño del vocabulario de bigramas.
#
# El suavizado se utiliza para ajustar las probabilidades y evitar problemas con trigramas que no se encuentran en los datos.

# %%
def get_prob_trigrams(trigramas: dict, bigrams: dict, alpha=0.1) -> dict:
    trigramas_prob = {}
    V = len(bigrams)  # Usamos el número de bigramas para el suavizado
    for trigrama, freq in trigramas.items():
        bigram = (trigrama[0], trigrama[1])
        trigramas_prob[trigrama] = (freq + alpha) / (bigrams[bigram] + V * alpha)  # P(w3|w1,w2)
    return trigramas_prob

# %% [markdown]
# #### Probabilidad de un Cuatrigrama
#
# La fórmula para calcular la probabilidad condicional de un cuatrigrama \( $P(w_4 \mid w_1, w_2, w_3)$ \) es la siguiente:
#
# $$
# P(w_4 \mid w_1, w_2, w_3) = \frac{\text{frecuencia}(w_1, w_2, w_3, w_4) + \alpha}{\text{frecuencia}(w_1, w_2, w_3) + \alpha \cdot |V|}
# $$
#
# Donde:
#
# - \( $\text{frecuencia}(w_1, w_2, w_3, w_4)$ \) es el número de veces que el cuatrigrama \( $(w_1, w_2, w_3, w_4)$ \) aparece en el corpus.
# - \( $\text{frecuencia}(w_1, w_2, w_3)$ \) es el número de veces que el trigrama \( $(w_1, w_2, w_3)$ \) aparece en el corpus.
# - \( $\alpha$ \) es el parámetro de suavizado.
# - \( $|V|$ \) es el tamaño del vocabulario de trigramas.
#
# El suavizado de Laplace ayuda a asegurar que se calculen probabilidades no nulas incluso para cuatrigramas raros o no observados en el corpus.

# %%
def get_prob_cuatrigramas(cuatrigramas: dict, trigramas: dict, alpha=0.1) -> dict:
    cuatrigramas_prob = {}
    V = len(trigramas)  # Suavizado usando trigramas
    for cuatrigrama, freq in cuatrigramas.items():
        trigrama = (cuatrigrama[0], cuatrigrama[1], cuatrigrama[2])
        cuatrigramas_prob[cuatrigrama] = (freq + alpha) / (trigramas[trigrama] + V * alpha)  # P(w4|w1,w2,w3)
    return cuatrigramas_prob

# %%
unigrams_prob , bigrams_prob =  get_prob_unigrams(unigrams) , get_prob_bigrams(bigrams,unigrams)
trigrams_prob , cuatrigrams_prob = get_prob_trigrams(trigrams,bigrams), get_prob_cuatrigramas(cuatrigrams,trigrams)

# %%
print('Top 5 unigramas mas probables:')
sorted(unigrams_prob.items(),key=lambda x : x[1], reverse=True)[:5]
# Out:
# Top 5 unigramas mas probables:
# [('el', 0.03980099502487562),
#  ('que', 0.03731343283582089),
#  ('a', 0.02736318407960199),
#  ('una', 0.024875621890547265),
#  ('de', 0.024875621890547265)]

# %%
print('Top 5 bigramas mas probables:')
sorted(bigrams_prob.items(),key=lambda x : x[1], reverse=True)[:5]
# Out:
# Top 5 bigramas mas probables:
# [(('como', 'si'), 0.12757201646090535),
#  (('envolvía', 'el'), 0.09012875536480687),
#  (('cambiado', 'las'), 0.09012875536480687),
#  (('vez', 'más'), 0.08641975308641975),
#  (('el', 'bosque'), 0.08310991957104559)]

# %%
print('Top 5 trigramas mas probables:')
sorted(trigrams_prob.items(),key=lambda x : x[1], reverse=True)[:5]
# Out:
# Top 5 trigramas mas probables:
# [(('a', 'su', 'alrededor'), 0.05303030303030303),
#  (('envolvía', 'el', 'lugar'), 0.05303030303030303),
#  (('el', 'misterio', 'del'), 0.02849740932642487),
#  (('misterio', 'del', 'bosque'), 0.02849740932642487),
#  (('del', 'bosque', 'encantado'), 0.02849740932642487)]

# %%
print('Top 5 cuatrigramas mas probables:')
sorted(cuatrigrams_prob.items(),key=lambda x : x[1], reverse=True)[:5]
# Out:
# Top 5 cuatrigramas mas probables:
# [(('el', 'misterio', 'del', 'bosque'), 0.026960784313725488),
#  (('misterio', 'del', 'bosque', 'encantado'), 0.026960784313725488),
#  (('del', 'bosque', 'encantado', 'una'), 0.026960784313725488),
#  (('bosque', 'encantado', 'una', 'fría'), 0.026960784313725488),
#  (('encantado', 'una', 'fría', 'tarde'), 0.026960784313725488)]

# %% [markdown]
# ### Predicción de la siguiente palabra según un contexto
#
# Para una ventana de \( s = 4 \), utilizamos un enfoque de **Naive Bayes** para combinar las probabilidades condicionales de unigramas, bigramas, trigramas y cuatrigramas con el fin de predecir la siguiente palabra en una secuencia.
#
# #### Expresión matemática
#
# La probabilidad de la siguiente palabra \( $w_4$ \) dado el contexto \( $w_1, w_2, w_3$ \) se puede calcular combinando las probabilidades condicionales de los n-gramas como sigue:
#
# $$
# P(w_4 \mid w_1, w_2, w_3) \propto P(w_4 \mid w_1, w_2, w_3) \cdot P(w_4 \mid w_2, w_3) \cdot P(w_4 \mid w_3) \cdot P(w_4)
# $$
#
# Donde:
#
# - \( $P(w_4 \mid w_1, w_2, w_3)$ \) es la probabilidad condicional basada en los **cuatrigramas**.
# - \( $P(w_4 \mid w_2, w_3)$ \) es la probabilidad condicional basada en los **trigramas**.
# - \( $P(w_4 \mid w_3)$ \) es la probabilidad condicional basada en los **bigramas**.
# - \( $P(w_4)$ \) es la probabilidad basada en los **unigramas**.
#
# Cada una de estas probabilidades se suaviza utilizando el suavizado de Laplace para evitar probabilidades de cero cuando una secuencia no ha sido observada. La fórmula general para cada n-grama con suavizado de Laplace es la siguiente:

# %%
def predict_next_word_naive_bayes(w1, w2, w3, unigrams, bigrams, trigrams, cuatrigramas, alpha=0.1):
    # Lista de palabras candidatas (por simplicidad, usamos el vocabulario de unigramas)
    vocabulario = list(unigrams.keys())
    max_prob = 0
    best_word = None
    # Alamacenamos las probabilidades de cada palabra candidata
    probs = {}
    
    # Iterar por cada palabra candidata en el vocabulario
    for w4 in vocabulario:
        # Calcular las probabilidades individuales para cada n-grama
        # Cuatrigrama
        if (w1, w2, w3, w4) in cuatrigramas:
            p_cuatrigrama = (cuatrigramas[(w1, w2, w3, w4)] + alpha) / (trigrams[(w1, w2, w3)] + alpha * len(vocabulario))
        else:
            p_cuatrigrama = alpha / (trigrams.get((w1, w2, w3), 0) + alpha * len(vocabulario))

        # Trigrama
        if (w2, w3, w4) in trigrams:
            p_trigrama = (trigrams[(w2, w3, w4)] + alpha) / (bigrams[(w2, w3)] + alpha * len(vocabulario))
        else:
            p_trigrama = alpha / (bigrams.get((w2, w3), 0) + alpha * len(vocabulario))

        # Bigrama
        if (w3, w4) in bigrams:
            p_bigrama = (bigrams[(w3, w4)] + alpha) / (unigrams[w3] + alpha * len(vocabulario))
        else:
            p_bigrama = alpha / (unigrams.get(w3, 0) + alpha * len(vocabulario))

        # Unigrama (para suavizado en general)
        p_unigrama = (unigrams[w4] + alpha) / (sum(unigrams.values()) + alpha * len(vocabulario))

        # Calcular la probabilidad conjunta usando Naive Bayes (producto de las probabilidades)
        prob_total = p_cuatrigrama * p_trigrama * p_bigrama * p_unigrama
        #print(f'{w4} : {prob_total}')
        probs[w4] = prob_total

        # Mantener la palabra con la probabilidad más alta
        if prob_total > max_prob:
            max_prob = prob_total
            best_word = w4

    return best_word,probs

def predict_words(frase:str,unigrams:dict,bigrams:dict,trigrams:dict,cuatrigrams:dict, k:int,alpha=0.1):
    words = tokenizer(frase)
    n = len(words)
    if n < 3:
        return None
    w1 = words[-3]
    w2 = words[-2]
    w3 = words[-1]
    new_words = []
    for i in range(k):
        new_word,probs = predict_next_word_naive_bayes(w1,w2,w3,unigrams,bigrams,trigrams,cuatrigrams,alpha)
        # Imprimir la palabra predicha y su probabilidad   
        print(f'{w1} {w2} {w3} {new_word} : {probs[new_word]}')

        # Actualizar las palabras para la siguiente iteración
        w1 = w2
        w2 = w3
        w3 = new_word

        
        new_words.append(new_word)
    return new_words


# Ejemplo de uso
w1 = 'troncos'
w2 = 'de'
w3 = 'los'
frase = w1 + ' ' + w2 + ' ' + w3
new_words,probs = predict_next_word_naive_bayes(w1,w2,w3,unigrams, bigrams, trigrams, cuatrigrams)
print(f"Siguiente palabra: {frase} -> ", new_words)
print(sorted(probs.items(),key=lambda x : x[1], reverse=True)[:5])

# predecir las siguientes 5 palabras
frase = 'the human is'
predict_words(frase,unigrams,bigrams,trigrams,cuatrigrams,5,alpha=0.1)
# Out:
# Siguiente palabra: troncos de los ->  the
# [('the', 3.4580450139140344e-13), ('of', 1.5872695243526675e-13), ('and', 1.5573028689134696e-13), ('to', 1.5530219181364413e-13), ('i', 1.5508814427479272e-13)]
# the human is the : 5.995071190146243e-11
# human is the one : 1.3006308809907175e-11
# is the one which : 3.139606256027356e-10
# the one which is : 1.3420561807506389e-09
# one which is the : 1.7866139659432056e-09
# ['the', 'one', 'which', 'is', 'the']

# %%
# Lectura del corpus
path_corpus = './corpus/arthur-conan-doyle.tok.test.txt'

def leer_corpus(archivo):
    try:
        with open(archivo, 'r', encoding='utf-8') as f:
            return f.read()
    except UnicodeDecodeError:
        # Si utf-8 falla, intentamos con latin-1
        with open(archivo, 'r', encoding='latin-1') as f:
            return f.read()

# Leer el archivo
corpus = leer_corpus(path_corpus)
# Imprimimos un extracto del corpus
print("\nExtracto del corpus:")
print(corpus[:2000])
# Imprimimos la longitud del corpus
print("\nLongitud del corpus:", len(corpus))

unigrams,bigrams,trigrams,cuatrigrams = get_unigrams_bigrams_trigramas_cuatrigramas(tokenizer(corpus))

unigrams_prob , bigrams_prob =  get_prob_unigrams(unigrams) , get_prob_bigrams(bigrams,unigrams)
trigrams_prob , cuatrigrams_prob = get_prob_trigrams(trigrams,bigrams), get_prob_cuatrigramas(cuatrigrams,trigrams)
# Out:
# Extracto del corpus:
# VI . The Musgrave Ritual
# An anomaly which often struck me in the character of my friend Sherlock Holmes was that , although in his methods of thought he was the neatest and most methodical of mankind , and although also he affected a certain quiet primness of dress , he was none the less in his personal habits one of the most untidy men that ever drove a fellow - lodger to distraction . Not that I am in the least conventional in that respect myself . The rough - and - tumble work in Afghanistan , coming on the top of a natural Bohemianism of disposition , has made me rather more lax than befits a medical man . But with me there is a limit , and when I find a man who keeps his cigars in the coal - scuttle , his tobacco in the toe end of a Persian slipper , and his unanswered correspondence transfixed by a jack - knife into the very centre of his wooden mantelpiece , then I begin to give myself virtuous airs . I have always held , too , that pistol practice should be distinctly an open - air pastime ; and when Holmes , in one of his queer humours , would sit in an armchair with his hair - trigger and a hundred Boxer cartridges , and proceed to adorn the opposite wall with a patriotic V. R. done in bullet - pocks , I felt strongly that neither the atmosphere nor the appearance of our room was improved by it .
# Our chambers were always full of chemicals and of criminal relics which had a way of wandering into unlikely positions , and of turning up in the butter - dish or in even less desirable places . But his papers were my great crux . He had a horror of destroying documents , especially those which were connected with his past cases , and yet it was only once in every year or two that he would muster energy to docket and arrange them ; for , as I have mentioned somewhere in these incoherent memoirs , the outbursts of passionate energy when he performed the remarkable feats with which his name is associated were followed by reactions of lethargy during which he would l
#
# Longitud del corpus: 308998

# %%
# Ejemplo de uso
w1 = 'the'
w2 = 'human'
w3 = 'is'
frase = w1 + ' ' + w2 + ' ' + w3
new_words,probs = predict_next_word_naive_bayes(w1,w2,w3,unigrams, bigrams, trigrams, cuatrigrams)
print(f"Siguiente palabra: {frase} -> ", new_words)
sorted(probs.items(),key=lambda x : x[1], reverse=True)[:5]
# Out:
# Siguiente palabra: the human is ->  the
# [('the', 5.995071190146243e-11),
#  ('a', 4.3329334381382753e-11),
#  ('of', 1.255345683906054e-11),
#  ('to', 7.402095534383316e-12),
#  ('that', 4.8566846931888605e-12)]

# %% [markdown]
# # Constuyendo la clase Generadora

# %%
import re
from collections import defaultdict
import numpy as np
import math

class NaiveBayesNGramModel:
    def __init__(self, corpus_path: str):
        self.corpus_path = corpus_path
        self.corpus = self.leer_corpus()
        self.corpus_tokenized = self.tokenizer(self.corpus)

        # Inicializamos unigramas, bigramas, trigramas y cuatrigramas
        self.unigrams, self.bigrams, self.trigrams, self.cuatrigramas = self.get_unigrams_bigrams_trigramas_cuatrigramas(self.corpus_tokenized)

        # Calculamos las probabilidades de n-gramas con enfoque Naive Bayes
        self.unigrams_prob = self.get_prob_unigrams(self.unigrams)
        self.bigrams_prob = self.get_prob_bigrams(self.bigrams, self.unigrams)
        self.trigrams_prob = self.get_prob_trigrams(self.trigrams,self.bigrams)
        self.cuatrigrams_prob = self.get_prob_cuatrigramas(self.cuatrigramas,self.trigrams)

    # Lectura del corpus desde archivo
    def leer_corpus(self):
        try:
            with open(self.corpus_path, 'r', encoding='utf-8') as f:
                return f.read()
        except UnicodeDecodeError:
            with open(self.corpus_path, 'r', encoding='latin-1') as f:
                return f.read()

    # Tokenizador
    def tokenizer(self, corpus: str) -> list:
        """
        Tokeniza el texto eliminando caracteres especiales, metadatos y convirtiendo a minúsculas.
        """
        # Eliminar metadatos como "Provincia:", "Fecha:", "Temas:", y etiquetas como [HS:].
        corpus_cleaned = re.sub(r"Provincia:.*|Enclave:.*|Fecha:.*|Duraci.*|Informantes:.*|Encuesta:.*|Transcripci.*|Temas:.*", "", corpus)
        
        # Eliminar anotaciones dentro de corchetes como [HS:E1], [RISA], etc.
        corpus_cleaned = re.sub(r"\[.*?\]", "", corpus_cleaned)

        # Eliminar múltiples espacios y líneas vacías
        corpus_cleaned = re.sub(r"\s+", " ", corpus_cleaned).strip()

        # Convertir a minúsculas y tokenizar por palabras alfanuméricas
        corpus_cleaned = corpus_cleaned.lower()
        pattern = re.compile(r'\b\w+\b')  # Tokenizar solo palabras alfanuméricas
        return re.findall(pattern, corpus_cleaned)

    # Función para obtener unigramas, bigramas, trigramas y cuatrigramas
    def get_unigrams_bigrams_trigramas_cuatrigramas(self, corpus_tokenized: list):
        unigrams = defaultdict(int)
        bigrams = defaultdict(int)
        trigramas = defaultdict(int)
        cuatrigramas = defaultdict(int)

        n = len(corpus_tokenized)
        if n < 4:
            return None, None, None, None

        for i in range(n - 3):
            unigram = corpus_tokenized[i]
            bigram = (corpus_tokenized[i], corpus_tokenized[i + 1])
            trigrama = (corpus_tokenized[i], corpus_tokenized[i + 1], corpus_tokenized[i + 2])
            cuatrigrama = (corpus_tokenized[i], corpus_tokenized[i + 1], corpus_tokenized[i + 2], corpus_tokenized[i + 3])

            unigrams[unigram] += 1
            bigrams[bigram] += 1
            trigramas[trigrama] += 1
            cuatrigramas[cuatrigrama] += 1

        # Agregamos los últimos n-gramas
        unigrams[corpus_tokenized[n - 3]] += 1
        unigrams[corpus_tokenized[n - 2]] += 1
        unigrams[corpus_tokenized[n - 1]] += 1
        bigrams[(corpus_tokenized[n - 3], corpus_tokenized[n - 2])] += 1
        bigrams[(corpus_tokenized[n - 2], corpus_tokenized[n - 1])] += 1
        trigramas[(corpus_tokenized[n - 3], corpus_tokenized[n - 2], corpus_tokenized[n - 1])] += 1

        return dict(unigrams), dict(bigrams), dict(trigramas), dict(cuatrigramas)

    # PROBABILIDADES CONDICIONALES USANDO NAIVE BAYES CON SUAVIZADO
    def get_prob_unigrams(self, unigrams: dict) -> dict:
        unigrams_prob = {}
        total_count = sum(unigrams.values())  # Total de ocurrencias de unigramas
        for unigram, freq in unigrams.items():
            unigrams_prob[unigram] = freq / total_count  # P(w) = freq(w) / total unigrams
        return unigrams_prob

    def get_prob_bigrams(self, bigrams: dict, unigrams: dict, alpha=0.1) -> dict:
        bigrams_prob = {}
        V = len(unigrams)  # Tamaño del vocabulario (suavizado Laplace)
        for bigram, freq in bigrams.items():
            bigrams_prob[bigram] = (freq + alpha) / (unigrams[bigram[0]] + V * alpha)  # P(w2|w1)
        return bigrams_prob

    def get_prob_trigrams(self, trigramas: dict, bigrams: dict, alpha=0.1) -> dict:
        trigramas_prob = {}
        V = len(bigrams)  # Usamos el número de bigramas para el suavizado
        for trigrama, freq in trigramas.items():
            bigram = (trigrama[0], trigrama[1])
            trigramas_prob[trigrama] = (freq + alpha) / (bigrams[bigram] + V * alpha)  # P(w3|w1,w2)
        return trigramas_prob

    def get_prob_cuatrigramas(self, cuatrigramas: dict, trigramas: dict, alpha=0.1) -> dict:
        cuatrigramas_prob = {}
        V = len(trigramas)  # Suavizado usando trigramas
        for cuatrigrama, freq in cuatrigramas.items():
            trigrama = (cuatrigrama[0], cuatrigrama[1], cuatrigrama[2])
            cuatrigramas_prob[cuatrigrama] = (freq + alpha) / (trigramas[trigrama] + V * alpha)  # P(w4|w1,w2,w3)
        return cuatrigramas_prob

    # FUNCIÓN PARA GENERAR K PALABRAS BASADO EN EL MODELO
    def predict_next_word_naive_bayes(self,w1, w2, w3, unigrams, bigrams, trigrams, cuatrigramas, alpha=0.1):
        # Lista de palabras candidatas (por simplicidad, usamos el vocabulario de unigramas)
        vocabulario = list(unigrams.keys())
        max_prob = 0
        best_word = None
        # Alamacenamos las probabilidades de cada palabra candidata
        probs = {}
        
        # Iterar por cada palabra candidata en el vocabulario
        for w4 in vocabulario:
            # Calcular las probabilidades individuales para cada n-grama
            # Cuatrigrama
            if (w1, w2, w3, w4) in cuatrigramas:
                p_cuatrigrama = (cuatrigramas[(w1, w2, w3, w4)] + alpha) / (trigrams[(w1, w2, w3)] + alpha * len(vocabulario))
            else:
                p_cuatrigrama = alpha / (trigrams.get((w1, w2, w3), 0) + alpha * len(vocabulario))

            # Trigrama
            if (w2, w3, w4) in trigrams:
                p_trigrama = (trigrams[(w2, w3, w4)] + alpha) / (bigrams[(w2, w3)] + alpha * len(vocabulario))
            else:
                p_trigrama = alpha / (bigrams.get((w2, w3), 0) + alpha * len(vocabulario))

            # Bigrama
            if (w3, w4) in bigrams:
                p_bigrama = (bigrams[(w3, w4)] + alpha) / (unigrams[w3] + alpha * len(vocabulario))
            else:
                p_bigrama = alpha / (unigrams.get(w3, 0) + alpha * len(vocabulario))

            # Unigrama (para suavizado en general)
            p_unigrama = (unigrams[w4] + alpha) / (sum(unigrams.values()) + alpha * len(vocabulario))

            # Calcular la probabilidad conjunta usando Naive Bayes (producto de las probabilidades)
            prob_total = p_cuatrigrama * p_trigrama * p_bigrama * p_unigrama
            #print(f'{w4} : {prob_total}')
            probs[w4] = prob_total

            # Mantener la palabra con la probabilidad más alta
            if prob_total > max_prob:
                max_prob = prob_total
                best_word = w4

        return best_word,probs

    def predict_words(self, frase: str, k: int, alpha=0.1):
        words = self.tokenizer(frase)
        n = len(words)
        if n < 3:
            return None
        w1 = words[-3]
        w2 = words[-2]
        w3 = words[-1]
        new_words = []
        for i in range(k):
            new_word, probs = self.predict_next_word_naive_bayes(w1, w2, w3, self.unigrams, self.bigrams, self.trigrams, self.cuatrigramas, alpha)

            # Ordenamos las probabilidades y seleccionamos el top 5
            top_5_probs_ord = sorted(probs.items(), key=lambda x: x[1], reverse=True)[:5]
            
            # Seleccionar una palabra aleatoria del top 5
            selected_word, selected_prob = top_5_probs_ord[np.random.randint(5)]
            
            # Imprimir la palabra predicha y su probabilidad
            print(f'{w1} {w2} {w3} {selected_word} : {selected_prob}')

            # Actualizar las palabras para la siguiente iteración
            w1 = w2
            w2 = w3
            w3 = selected_word

            new_words.append(selected_word)

        continuacion = ' '.join(new_words)
        return continuacion
    
    def calcular_entropia(self, test_text:str)->float:
        text_tokenized = self.tokenizer(test_text)
        total_words = len(text_tokenized)
        
        entropia = 0.0
        
        for i in range(total_words-3):
            cuatrigram = (text_tokenized[i],text_tokenized[i+1],text_tokenized[i+2],text_tokenized[i+3])
            trigram =(text_tokenized[i],text_tokenized[i+1],text_tokenized[i+2])
            bigram = (text_tokenized[i],text_tokenized[i+1])
            unigram = text_tokenized[i] 
            print(f'secuencia: {cuatrigram}')

            if cuatrigram in self.cuatrigrams_prob:
                p = self.cuatrigrams_prob[cuatrigram]                
                entropia += -math.log2(p)
                print(f'Se encontro cuatrigrama: {cuatrigram} [p:{p}] - [e:{entropia}]')
            elif trigram in self.trigrams_prob:
                
                p = self.trigrams_prob[trigram]
                entropia += -math.log2(p)
                print(f'Se encontro trigrama: {trigram} [p:{p}] - [e:{entropia}]')
            elif bigram in self.bigrams_prob:

                p = self.bigrams_prob[bigram]
                entropia += -math.log2(p)
                print(f'Se encontro bigrama: {bigram} [p:{p}] - [e:{entropia}]')
            elif unigram in self.unigrams_prob:
                p = self.unigrams_prob[unigram]
                entropia += -math.log2(p)
                print(f'Se encontro unigrama: {unigram} [p:{p}] - [e:{entropia}]')


        return entropia/total_words
    
    def calcular_perplejidad(self,test_text:str)->float:
        entropia = self.calcular_entropia(test_text)
        perplejidad = np.exp(entropia)
        print(f'entropia : {entropia}')
        print(f'Perplejidad (np.exp(entropia)): {perplejidad}')
        return perplejidad

# %%
# Ejemplo de uso:
path_corpus = './corpus/arthur-conan-doyle.tok.test.txt'
model = NaiveBayesNGramModel(path_corpus)

# %%
frase = 'the human is'
next_words = model.predict_words(frase=frase,k=12)
print(f'Frase predicha: [{frase}] {next_words}')
# Out:
# the human is to : 7.402095534383316e-12
# human is to him : 1.4517975459305605e-11
# is to him the : 6.29533609210717e-09
# to him the young : 9.410074132252732e-13
# him the young and : 1.548982979666425e-12
# the young and to : 8.958372933314113e-12
# young and to see : 2.978602786523119e-11
# and to see you : 2.7280393569639796e-10
# to see you have : 9.655515288715098e-12
# see you have been : 2.515639709128347e-10
# you have been in : 7.263334517401634e-11
# have been in which : 5.933035310408693e-12
# Frase predicha: [the human is] to him the young and to see you have been in which

# %% [markdown]
# ### Cálculo de Entropía en un Modelo de Naive Bayes basado en N-gramas
#
# #### Entropía
#
# La **entropía** es una medida de la incertidumbre en la predicción de la siguiente palabra en una secuencia de texto. Cuanto mayor sea la entropía, más impredecible es la siguiente palabra, y viceversa. Se calcula como la suma del logaritmo negativo de las probabilidades condicionales de cada n-grama (cuatrigrama, trigrama, bigrama, unigrama) observado en el texto de prueba.
#
# La fórmula de la entropía para un texto tokenizado se puede expresar de la siguiente manera:
#
# $$
# H = - \frac{1}{N} \sum_{i=1}^{N} \log_2 P(w_i \mid w_{i-3}, w_{i-2}, w_{i-1})
# $$
#
# Donde:
#
# - \( $P(w_i \mid w_{i-3}, w_{i-2}, w_{i-1})$ \) es la probabilidad condicional de la palabra \( $w_i$ \) dada la historia de las tres palabras anteriores, basada en el modelo de cuatrigramas. Si no hay cuatrigramas disponibles, se utilizan trigramas, bigramas o unigramas.
# - \( N \) es el número total de palabras en el texto de prueba.
#
# El código implementado para calcular la entropía recorre el texto de prueba y, dependiendo de la disponibilidad de n-gramas, ajusta las probabilidades para las diferentes secuencias.

# %%
entropia = model.calcular_entropia('the direction of your life')
# Out:
# secuencia: ('the', 'direction', 'of', 'your')
# Se encontro trigrama: ('the', 'direction', 'of') [p:0.0010202402501234163] - [e:9.936875361045546]
# secuencia: ('direction', 'of', 'your', 'life')
# Se encontro bigrama: ('direction', 'of') [p:0.005547602004294917] - [e:17.430795356068135]

# %%
print(f'entropia: {entropia}')
# Out:
# entropia: 3.486159071213627

# %% [markdown]
# ### Cálculo de Perplejidad en un Modelo de Naive Bayes basado en N-gramas
#
# #### Perplejidad
#
# La **perplejidad** es una métrica utilizada para evaluar qué tan bien un modelo de lenguaje predice una secuencia de texto. Cuanto más baja es la perplejidad, mejor es el modelo para predecir las palabras siguientes. En otras palabras, la perplejidad es una medida de incertidumbre: indica cuántas palabras diferentes el modelo considera probables en promedio.
#
# La perplejidad \( PP \) está relacionada directamente con la entropía \( H \), y se calcula de la siguiente manera:
#
# $$
# PP = 2^H
# $$
#
# O alternativamente:
#
# $$
# PP = e^H
# $$
#
# Donde:
#
# - \( H \) es la entropía del modelo. Si la entropía es baja, significa que el modelo asigna probabilidades más altas a las palabras correctas, lo que da lugar a una perplejidad baja.
# - Una perplejidad baja indica que el modelo de lenguaje es bueno para predecir la secuencia de palabras.

# %%
perplejidad = model.calcular_perplejidad('You build the direction of your life')
# Out:
# secuencia: ('you', 'build', 'the', 'direction')
# Se encontro unigrama: you [p:0.012897232989764385] - [e:6.2767946109585155]
# secuencia: ('build', 'the', 'direction', 'of')
# secuencia: ('the', 'direction', 'of', 'your')
# Se encontro trigrama: ('the', 'direction', 'of') [p:0.0010202402501234163] - [e:16.213669972004062]
# secuencia: ('direction', 'of', 'your', 'life')
# Se encontro bigrama: ('direction', 'of') [p:0.005547602004294917] - [e:23.70758996702665]
# entropia : 3.3867985667180927
# Perplejidad (np.exp(entropia)): 29.571130567096375

# %%
print(f'perplejidad: {perplejidad}')
# Out:
# perplejidad: 29.571130567096375

# %% [markdown]
# ## Probando otros Corpus

# %%
# Ejemplo de uso:
path_corpus = './corpus/COSER-0102-01.txt'
model = NaiveBayesNGramModel(path_corpus)

# %%
print(model.corpus[:1500])
# Out:
# Provincia:	Álava
# Enclave:	Berganzo (Zambrana) (0102)
# Fecha:	14 de julio de 1992
# Duración:	00:50:11:000
# Informantes:	I1: mujer, 71 años
# Encuesta:	José Ignacio Sanjuán, Reyes Fernández Sánchez, Teodora Fernández Olmo
# Transcripción:	María José González Arévalo, César Fernández Ripoll, Aitana Cerviño
# Temas:	2. Alimentación (pan, horno, manteca, huevos, bollos, recetas, pescado)
# 3. Animales domésticos (burro, caballo, buey, conejo, gallina, gato, perro)
# 6. Agricultura (agricultor, campo, cereal, legumbres, huerto, patata, viñas)
# 7. Ganadería (cabra, oveja, vaca, pastor, leche, queso, lana, abejas, miel)
# 8. Otras industrias (excluyendo agricultura y ganadería)
# 14. Bodas y noviazgos (boda, anillos, ajuar)
# 15. Fiestas populares (romerías, fiestas patronales, carnaval)
# 16. Sanidad y salud (enfermedad, médico, parto, entierro)
# 17. Construcciones (la casa, tipos, dependencias, infraestructuras)
# 20. Caza, pesca y monte (leña, animales y plantas no domésticos)
# 22. Tiempo meteorológico
#
# I1: La merienda es o, o unos huevos fritos... [A-Inn] Bueno, bueno. [A-Err] [A-Inn] [HS:E1 Sí.] [RISA] [R-Anm]
# E1: |T7| Y, y, aparte del cerdo, ¿qué más animales tenían en casa?
# I1: Pues, hombre... Pues, había muchos. Los animales, los que tenías para labrar, los bueyes...
# E1: ¿Bueyes para labrar?
# I1: Yeguas, o caballos... ¿Machos? Sí. Cerdos, como siempre.
# E1: Y, ¡ah! ¿No tenían vacas [HS:I1 También.] para leche o...?
# I1: Sí. Pero, el que más tenía una, pa la casa. [HS:E1 [Asent].] O, no sé, entonces bien.

# %%
' '.join(model.corpus_tokenized)
# Out:
# '3 animales domésticos burro caballo buey conejo gallina gato perro 6 agricultura agricultor campo cereal legumbres huerto patata viñas 7 ganadería cabra oveja vaca pastor leche queso lana abejas miel 8 otras industrias excluyendo agricultura y ganadería 14 bodas y noviazgos boda anillos ajuar 15 fiestas populares romerías fiestas patronales carnaval 16 sanidad y salud enfermedad médico parto entierro 17 construcciones la casa tipos dependencias infraestructuras 20 caza pesca y monte leña animales y plantas no domésticos 22 tiempo meteorológico i1 la merienda es o o unos huevos fritos bueno bueno e1 t7 y y aparte del cerdo qué más animales tenían en casa i1 pues hombre pues había muchos los animales los que tenías para labrar los bueyes e1 bueyes para labrar i1 yeguas o caballos machos sí cerdos como siempre e1 y ah no tenían vacas para leche o i1 sí pero el que más tenía una pa la casa o no sé entonces bien e2 pero siempre ha habido aquí vacas en el pueblo i1 sí siempre hay había muchas para de estas de de echarlas al monte había muchas se se llevaban a toloño siempre y allí se estaban e1 y bebían la leche entonces i1 sí y poco buena que era y las cabras la leche de cabra e2 qué se hacía además de i1 quesos yo he hecho muchos quesos e2 quesos de vaca i1 no de de cabra e2 y cómo nos puede explicar cómo se hace el queso cómo lo hacía i1 cómo se hacía pues se ordeña y según se saca la leche que está calentita se le echa cuajo sabes lo que es el cuajo e2 sí para pa que se quede más espeso no i1 eso e1 y el cuajo compraban el cuajo o i1 no no yo lo sa yo matabámos los cabritos y cuando matabas el cabrito de allá sacabas el cuajo era todo natural ahora lo hacen artificial e2 pero el cuajo dónde lo echaban i1 a la leche se colaba bien la leche se colaba bien el cuajo con un trapito siempre un trapito y y así se colaba y se ponía así y lo tenías en la cocina así al calor y enseguida se cuajaba e2 pero junto o sea estaba la leche y i1 con el cuajo claro en un barreño en un eso lo echabas y y después que estaba cuajao pues a hacer el queso en unas ancellas que teníamos de mimbre eso y nada más ie e1 y el y el queso lo hacían con leche de cabra i1 yo hacía de cabra porque teníamos muchas cabras a ver qué me quiere e1 sí sí e2 e3 e1 y el queso era de cabra entonces no mezclaban las leches o i1 no yo no e2 bueno y y además de que poníamos en calor la leche qué pasaba luego i1 pues nada ya se cuajaba y yo le daba así dos cortes cuatro dos cortes que se hacían en cuatro trozos e2 pero se lo daba al queso i1 sí sí a la claro al cuajo e1 y después cuando ya estaba el queso cuánto tiempo lo tenían qué hacía lo ponía o i1 cuando estaba pues echarlo a las ancellas ancellas que se llamaban e2 qué son las ancellas i1 las unas de mimbre tenía de todos los tamaños pequeño grande e2 qué son ancellas i1 pues unas cositas de como unas cestitas de mimbre que ahora com ahora deben de ser de no sé de metal o no se de qué son moldes como moldes son pues ahí nada lo deja lo tenías lo escurrías lo ponías bien y luego lo tenías un rato y y ya se hacía el queso no luego ibas le dabas la vuelta le echabas la sal y ya está yo siempre le echo sal le echaba sal claro si si no sabía soso e2 no sabía fuerte i1 no no no hombre pa saberte fuerte a saber lo que le echas claro e2 y luego ya una vez que que le has echado la sal i1 pues nada pues al día siguiente lo sacabas y a secar e2 así en cualquier sitio i1 no los tenía en unas cestas largas de mimbre y además los vendía eh que no me los dejaban porque enseguida me los enseguida me los llevaban e2 y antes también se vendía mucho i1 sí e2 venía venía solamente o sea era solamente para la gente del pueblo i1 para la gente del pueblo bueno a salinillas también hemos bajao mucho a vender e2 ah pero bajaban ustedes no tenían que subir ellos i1 no e2 y también antes venían de de fuera del pueblo entonces o no i1 pa qué e2 a comprar i1 no hombre bueno si alguna vez venía alguno y se le antojaba solía llevar sí pero no yo cu ...

# %%
frase = 'cerdos ? ... que hacemos'
next_words = model.predict_words(frase=frase,k=20)

print(f'Frase predicha: [{frase}] {next_words}')
# Out:
# cerdos que hacemos y : 2.79751533591817e-11
# que hacemos y y : 1.0201430093719854e-09
# hacemos y y y : 1.00552626098232e-08
# y y y a : 2.94772833165009e-08
# y y a que : 1.9716877659464636e-08
# y a que no : 1.140965544359159e-09
# a que no se : 5.6520348565638604e-09
# que no se le : 6.58968946476951e-09
# no se le podía : 4.2031892796648823e-10
# se le podía lavar : 4.1661812980820137e-10
# le podía lavar i1 : 2.4081068976003e-08
# podía lavar i1 no : 1.8172046151135987e-07
# lavar i1 no no : 6.568227754914533e-07
# i1 no no no : 9.242703515672144e-08
# no no no no : 8.885754407014305e-09
# no no no no : 8.885754407014305e-09
# no no no no : 8.885754407014305e-09
# no no no no : 8.885754407014305e-09
# no no no no : 8.885754407014305e-09
# no no no no : 8.885754407014305e-09
# Frase predicha: [cerdos ? ... que hacemos] y y y a que no se le podía lavar i1 no no no no no no no no no

# %% [markdown]
# ### Corrección de la predicción de la siguiente palabra usando el top 5 de probabilidades
#
# En la función `predict_words`, para evitar que siempre se seleccione la palabra con mayor probabilidad, se implementó una selección aleatoria entre las 5 palabras con las probabilidades más altas.
#
# #### Ajustes realizados:
# 1. **Ordenar y seleccionar el top 5**:
#    ```python
#    top_5_probs_ord = sorted(probs.items(), key=lambda x: x[1], reverse=True)[:5]

# %%
frase = 'cerdos ? ... que hacemos'
next_words = model.predict_words(frase=frase,k=20)

print(f'Frase predicha: [{frase}] {next_words}')
# Out:
# cerdos que hacemos que : 1.843725074033327e-11
# que hacemos que se : 1.042597876552835e-09
# hacemos que se iba : 2.3146665819730145e-10
# que se iba con : 6.478361595908353e-10
# se iba con y : 1.847987995299701e-10
# iba con y y : 1.0117605688676961e-09
# con y y a : 2.7019547937170744e-09
# y y a hacer : 4.576809568464352e-10
# y a hacer eso : 4.94390702428132e-10
# a hacer eso y : 3.838640996690733e-10
# hacer eso y nada : 2.7802442877005545e-10
# eso y nada aquí : 2.9601154246047327e-10
# y nada aquí a : 1.829860065668699e-10
# nada aquí a que : 1.7367267472298898e-10
# aquí a que se : 1.025603616136326e-09
# a que se hacían : 4.508621583538604e-10
# que se hacían la : 2.2929333693383317e-10
# se hacían la era : 9.716719739558427e-11
# hacían la era pues : 6.629643087966012e-10
# la era pues a : 2.5120472792131404e-10
# Frase predicha: [cerdos ? ... que hacemos] que se iba con y y a hacer eso y nada aquí a que se hacían la era pues a

# %% [markdown]
# # Conclusión

# %% [markdown]
# Se pudo arreglar de cierta manera la repetición o bucle de palabras, sin embargo el predictor sigue siendo un tanto carente de sentido contextual. Por solo usar una ventana de 4 palabras. Usar más tambien haria que se hiciera un calculo muy grande por ello no es recomendable seguir espandiendo el Naive Bayes.Se recomienda migrar hacia enfoques más avanzados como el uso de word embeddings, los cuales capturan relaciones semánticas entre palabras en un espacio de alta dimensionalidad.
